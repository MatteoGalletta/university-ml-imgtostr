# %%
# !pip install torchvision matplotlib numpy tensorboard standard-imghdr torchnet scikit-learn opencv-python Levenshtein
# Out:
# Requirement already satisfied: torchvision in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (0.22.0+xpu)
# Requirement already satisfied: matplotlib in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (3.10.3)
# Requirement already satisfied: numpy in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (2.1.2)
# Requirement already satisfied: tensorboard in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (2.19.0)
# Requirement already satisfied: standard-imghdr in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (3.13.0)
# Requirement already satisfied: torchnet in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (0.0.4)
# Requirement already satisfied: scikit-learn in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (1.6.1)
# Requirement already satisfied: opencv-python in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (4.11.0.86)
# Requirement already satisfied: Levenshtein in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (0.27.1)
# Requirement already satisfied: torch==2.7.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torchvision) (2.7.0+xpu)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: filelock in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (4.12.2)
# Requirement already satisfied: setuptools in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (1.13.3)
# Requirement already satisfied: networkx in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (3.3)
# Requirement already satisfied: jinja2 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (2024.6.1)
# Requirement already satisfied: intel-cmplr-lib-rt==2025.0.4 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (2025.0.4)
# Requirement already satisfied: intel-cmplr-lib-ur==2025.0.4 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (2025.0.4)
# Requirement already satisfied: intel-cmplr-lic-rt==2025.0.4 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (2025.0.4)
# Requirement already satisfied: intel-sycl-rt==2025.0.4 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (2025.0.4)
# Requirement already satisfied: tcmlib==1.2.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (1.2.0)
# Requirement already satisfied: umf==0.9.1 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (0.9.1)
# Requirement already satisfied: intel-pti==0.10.1 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (0.10.1)
# Requirement already satisfied: pytorch-triton-xpu==3.3.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (3.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: absl-py>=0.4 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from tensorboard) (2.2.2)
# Requirement already satisfied: grpcio>=1.48.2 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from tensorboard) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from tensorboard) (3.8)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from tensorboard) (6.31.0)
# Requirement already satisfied: six>1.9 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from tensorboard) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: visdom in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torchnet) (0.2.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from Levenshtein) (3.13.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Requirement already satisfied: requests in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from visdom->torchnet) (2.32.3)
# Requirement already satisfied: tornado in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from visdom->torchnet) (6.5)
# Requirement already satisfied: jsonpatch in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from visdom->torchnet) (1.33)
# Requirement already satisfied: websocket-client in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from visdom->torchnet) (1.8.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from sympy>=1.13.3->torch==2.7.0->torchvision) (1.3.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from jsonpatch->visdom->torchnet) (3.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from requests->visdom->torchnet) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from requests->visdom->torchnet) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from requests->visdom->torchnet) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from requests->visdom->torchnet) (2025.4.26)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# imports
import numpy as np
from PIL import Image

import Levenshtein
import sys
sys.path.append('../core')
from main import process_image

# %% [markdown]
# # Evaluation random words

# %% [markdown]
# caricamento dataset

# %%
words_dir = "../dataset/words_dataset"
words_dataset = np.loadtxt(f'{words_dir}/dataset.txt', dtype=str, delimiter='\t', comments=[])

# %%
len(words_dataset)
# Out:
# 1500

# %%
results = []
for i, data in enumerate(words_dataset):
    img_path = f'{words_dir}/{data[0]}'
    print("Processing: ", img_path)
    print(data[1])
    img = Image.open(img_path)
    try:
        _, output = process_image(img)
        edit_distance = Levenshtein.distance(data[1], output)

        results.append({
            'path': img_path,
            'label': data[1],
            'output': output,
            'edit_distance': edit_distance
        })
        print(f'{output}\nEDIT DISTANCE: {edit_distance}\n')
    except Exception as e:
        raise e
# Out:
# Processing:  ../dataset/words_dataset/Lato-Medium/2e50447b593857e282acc3a924_32221.png
# .PD{Y8W€é$
# . P D{Y8W€é$
# EDIT DISTANCE: 2
#
# Processing:  ../dataset/words_dataset/Lato-Medium
# EDIT DISTANCE: 0
#
# Processing:  ../dataset/words_dataset/Lato-Medium/6878444d78476f4a535a_55815.png
# hxDMxGoJSZ
# hx D M xGoJ SZ
# EDIT DISTANCE: 4
#
# Processing:  ../dataset/words_dataset/Lato-Medium/c2b0e282ac624e4653c3a8792732_84677.png
# °€bNFSèy'2
# °€bN FSèy'2
# EDIT DISTANCE: 1
#
# Processing:  ../dataset/words_dataset/Lato-Medium/c2a343452778453843695b_48348.png
# £CE'xE8Ci[
# £cE'XE8ci [
# EDIT DISTANCE: 4
#
# Processing:  ../dataset/words_dataset/PTS56F/213132c3ac584b5244c3b237_42945.png
# !12ìXKRDò7
# ,J 2 7XKR 0ò 7
# EDIT DISTANCE: 8
#
# Processing:  ../dataset/words_dataset/PTS56F/29494620584a2863782b_58659.png
# )IF XJ(cx+
# J , F X7écX+
# EDIT DISTANCE: 7
#
# Processing:  ../dataset/words_dataset/PTS56F/6e4441746c6b5545c3a97b_21018.png
# nDAtlkUEé{
# n 0q tZ K 0Eé £
# EDIT DISTANCE: 11
#
# Processing:  ../dataset/words_dataset/PTS56F/5d64235831593f536271_89142.png
# ]d#X1Y?Sbq
# Jd#XJ rPSòw
# EDIT DISTANCE: 7
#
# Processing:  ../dataset/words_dataset/PTS56F/48c2b06ac3ac52235a622e31_96798.png
# H°jìR#Zb.1
# H 17R #eò. J
# EDIT DISTANCE: 8
#
# Processing:  ../dataset/words_dataset/PTS56F/657147317b565a685575_35562.png
# eqG1{VZhUu
# e w G J mZh 0 j
# EDIT DISTANCE: 11
#
# Processing:  ../dataset/words_dataset/PTS56F/c3ac3a34762c4370657756_34324.png
# ì:4v,CpewV
# 7 .. 4 k X@ e ' P
# EDIT DISTANCE: 15
#
# Processing:  ../dataset/words_dataset/PTS56F/243e6b4f3f6a4632c2a357_19402.png
# $>kO?jF2£W
# $ > k 0 òF2 £ l
# EDIT DISTANCE: 9
#
# Processing:  ../dataset/words_dataset/PTS56F/4040406f3c36344a7164_74321.png
# @@@o<64Jqd
# @ @ @ 0<64jwd
# EDIT DISTANCE: 6
#
# Processing:  ../dataset/words_dataset/PTS56F/615bc2b0574d297b7b346a_41116.png
# a[°WM){{4j
# 1£ o lN £é~
# EDIT DISTANCE: 11
#
# Processing:  ../dataset/words_dataset/PTS56F/452441213e75507d686d_16782.png
# E$A!>uP}hm
# E$@ ,> j~ hm
# EDIT DISTANCE: 7
#
# Processing:  ../dataset/words_dataset/PTS56F/23302e687a634f717178_73932.png
# #0.hzcOqqx
# #0. hzc0wwX
# EDIT DISTANCE: 5
#
# Processing:  ../dataset/words_dataset/PTS56F/3462777323204a523a3c_16071.png
# 4bws# JR:<
# 4ò's# JR ..<
# EDIT DISTANCE: 5
#
# Processing:  ../dataset/words_dataset/PTS56F/26c2a334453f3637274631_87283.png
# &£4E?67'F1
# & £4EP67,FJ
# EDIT DISTANCE: 4
#
# Processing:  ../dataset/words_dataset/PTS56F/62455dc3a97929355a4de282ac_29748.png
# bE]éy)5ZM€
# ò E7 éM 5zM€
# EDIT DISTANCE: 7
#
# Processing:  ../dataset/words_dataset/PTS56F/e282ac2c38c3a92e3238736cc3a9_62090.png
# €,8é.28slé
# € 8é.2 8SZé
# EDIT DISTANCE: 4
#
# Processing:  ../dataset/words_dataset/PTS56F/313424693c5c63307227_78690.png
# 14$i<\c0r'
# J 4$Z<\c0r,
# EDIT DISTANCE: 4
#
# Processing:  ../dataset/words_dataset/PTS56F/206121484f5163776f56_45609.png
#  a!HOQcwoV
# 1 ,H0QC'0 p
# EDIT DISTANCE: 9
#
# Processing:  ../dataset/words_dataset/PTS56F/4f3e657263525558544d_28245.png
# O>ercRUXTM
# 0 > e rc R 0XrM
# EDIT DISTANCE: 8
#
# Processing:  ../dataset/words_dataset/PTS56F/6732c2a3356c2944427438_19911.png
# g2£5l)DBt8
# ù 2 £5 Z2 08 t8
# EDIT DISTANCE: 10
#
# Processing:  ../dataset/words_dataset/PTS56F/6b34383c444f56783261_12708.png
# k48<DOVx2a
# K 4 8 < 0 0 Px 2 1
# EDIT DISTANCE: 13
#
# Processing:  ../dataset/words_dataset/PTS56F/c3a84e434269c3a978613674_86405.png
# èNCBiéxa6t
# é N x8 Z éX1 6 t
# EDIT DISTANCE: 12
#
# Processing:  ../dataset/words_dataset/PTS56F/7d2c33323121637a7546_68037.png
# },321!czuF
# j, 32J ,czJF
# EDIT DISTANCE: 6
#
# Processing:  ../dataset/words_dataset/PTS56F/2b352f6e2d4665782b40_97986.png
# +5/n-Fex+@
# + 5an - 8eX+ @
# EDIT DISTANCE: 7
#
# Processing:  ../dataset/words_dataset/PTS56F/6a4f4d39415c48292c7e_48270.png
# jOM9A\H),~
# J 0 M 9q \H2 , ~
# EDIT DISTANCE: 10
#
# Processing:  ../dataset/words_dataset/PTS56F/c3a968613a793151343b36_21187.png
# éha:y1Q4;6
# éh1 ..yJ Q4,.6
# EDIT DISTANCE: 8
#
# Processing:  ../dataset/words_dataset/PTS56F/615d547127716c754f40_46293.png
# a]Tq'qluO@
# 1, M ,W z J 0 @
# EDIT DISTANCE: 14
#
# Processing:  ../dataset/words_dataset/PTS56F/61745a6d3a246a5745c3a8_89186.png
# atZm:$jWEè
# 1 tem .. & lEé
# EDIT DISTANCE: 11
#
# Processing:  ../dataset/words_dataset/PTS56F/31302d716d315a425c25_90698.png
# 10-qm1ZB\%
# J 0-wm J Z8\%
# EDIT DISTANCE: 7
#
# Processing:  ../dataset/words_dataset/PTS56F/7a4b633f71343c395638_38719.png
# zKc?q4<9V8
# z Kc Pw 4 < 9 P8
# EDIT DISTANCE: 9
#
# Processing:  ../dataset/words_dataset/PTS56F/5c317867293c54687449_40764.png
# \1xg)<ThtI
# \J Xù, < rh t ,
# EDIT DISTANCE: 11
#
# Processing:  ../dataset/words_dataset/PTS56F/c2b069316dc3ac686f587851_57189.png
# °i1mìhoXxQ
# O Z J m 7 h 0Xx Q
# EDIT DISTANCE: 12
#
# Processing:  ../dataset/words_dataset/PTS56F/5b4d503b705c4b7a6e30_49196.png
# [MP;p\Kzn0
# éMP,.@ \Kz n 0
# EDIT DISTANCE: 7
#
# Processing:  ../dataset/words_dataset/PTS56F/435231c3a8c2b07a3566456d_87704.png
# CR1è°z5fEm
# XR J é Oz 5,Em
# EDIT DISTANCE: 9
#
# Processing:  ../dataset/words_dataset/PTS56F/383864557a44c2b067e282ac4d_51432.png
# 88dUzD°g€M
# 88d0z0 Où€M
# EDIT DISTANCE: 5
#
# Processing:  ../dataset/words_dataset/PTS56F/4f6fc2a33ec3b27537516179_69300.png
# Oo£>òu7Qay
# 00 £>ò j 7Q1y
# EDIT DISTANCE: 7
#
# Processing:  ../dataset/words_dataset/PTS56F/337d2564c3b925c3b24f6147_99870.png
# 3}%dù%òOaG
# 3J % d ù % ò 0 1 G
# EDIT DISTANCE: 11
#
# Processing:  ../dataset/words_dataset/PTS56F/69c3a8397e6133305b52c3ac_31705.png
# iè9~a30[Rì
# Zé 9~130éR7
# EDIT DISTANCE: 6
#
# Processing:  ../dataset/words_dataset/PTS56F/c3a953e282ac3b63307679c3b92f_65800.png
# éS€;c0vyù/
# é s€,.c 0 Py ùZ
# EDIT DISTANCE: 9
#
# Processing:  ../dataset/words_dataset/PTS56F/2552463bc3b9c3b25b2f7530_33312.png
# %RF;ùò[/u0
# % R F,. ù ò -J 0
# EDIT DISTANCE: 10
#
# Processing:  ../dataset/words_dataset/PTS56F/7b6b4f5865c3ac5c6c4d26_20353.png
# {kOXeì\lM&
# ék 0Xe 7 \Z M &
# EDIT DISTANCE: 9
#
# Processing:  ../dataset/words_dataset/PTS56F/2c504b537a2c556e632e_41502.png
# ,PKSz,Unc.
# , PKsz, 0nc.
# EDIT DISTANCE: 4
#
# Processing:  ../dataset/words_dataset/PTS56F/c3a9755362505940c3a85a5a_90728.png
# éuSbPY@èZZ
# é J s ò P r @ éez
# EDIT DISTANCE: 14
#
# Processing:  ../dataset/words_dataset/PTS56F/556b53247a7a4356542d_43421.png
# UkS$zzCVT-
# 0KS$zz X#
# EDIT DISTANCE: 6
#
# Processing:  ../dataset/words_dataset/PTS56F/c2a3724bc2a359493c433527_23332.png
# £rK£YI<C5'
# £rK£ r, < x5 ,
# EDIT DISTANCE: 8
#
# Processing:  ../dataset/words_dataset/PTS56F/46c3b94e49393b45c2a34b28_26379.png
# FùNI9;E£K(
# Fù N , 9 ,.E£K#
# EDIT DISTANCE: 8
#
# Processing:  ../dataset/words_dataset/PTS56F/4c2b5c36714f66634371_68869.png
# L+\6qOfcCq
# [ + \ 6 w 0yc Gw
# EDIT DISTANCE: 12
#
# Processing:  ../dataset/words_dataset/PTS56F/305c4b332b236f752e6c_38742.png
# 0\K3+#ou.l
# 0\K3+ #0 j. Z
# EDIT DISTANCE: 6
#
# Processing:  ../dataset/words_dataset/PTS56F/c2a33e6b622b494959645b_30161.png
# £>kb+IIYd[
# £ > kò + , , Md£
# EDIT DISTANCE: 11
#
# Processing:  ../dataset/words_dataset/PTS56F/7e78567d58313e5a4a5d_45261.png
# ~xV}X1>ZJ]
# ~X KXJ >47
# EDIT DISTANCE: 8
#
# Processing:  ../dataset/words_dataset/PTS56F/7834722956206578c3b97e_90121.png
# x4r)V exù~
# x4# P exù~
# EDIT DISTANCE: 3
#
# Processing:  ../dataset/words_dataset/PTS56F/28316a43764038293525_53062.png
# (1jCv@8)5%
# <]j cP @ 82 5 %
# EDIT DISTANCE: 10
#
# Processing:  ../dataset/words_dataset/PTS56F/5329745c694f59c3a95a7a_53743.png
# S)t\iOYéZz
# N t\Z 0 Méez
# EDIT DISTANCE: 8
#
# Processing:  ../dataset/words_dataset/PTS56F/4a2351c3a857c3a9e282ac453168_87946.png
# J#QèWé€E1h
# j # Q é lé€E J h
# EDIT DISTANCE: 10
#
# Processing:  ../dataset/words_dataset/PTS56F/74c2b0326c2b5662542e69_41531.png
# t°2l+VbT.i
# t o2z+ pò £z
# EDIT DISTANCE: 9
#
# Processing:  ../dataset/words_dataset/PTS56F/212b33c3b279682c437338_42715.png
# !+3òyh,Cs8
# ,+ 3 òyh, GS 8
# EDIT DISTANCE: 7
#
# Processing:  ../dataset/words_dataset/PTS56F/c3b25570207a5a52543677_77146.png
# òUp zZRT6w
# ò0@ zzRr6'
# EDIT DISTANCE: 5
#
# Processing:  ../dataset/words_dataset/PTS56F/6f23346454733b41785b_19891.png
# o#4dTs;Ax[
# 0 # 4 d a ,q X£
# EDIT DISTANCE: 12
#
# Processing:  ../dataset/words_dataset/PTS56F/3578786858c3a874403b5a_75715.png
# 5xxhXèt@;Z
# 5xx hXé t @ ,.e
# EDIT DISTANCE: 8
#
# Processing:  ../dataset/words_dataset/PTS56F/437d5a4c4c637a6134c3ac_39380.png
# C}ZLLcza4ì
# g z[ [ CZ1 47
# EDIT DISTANCE: 12
#
# Processing:  ../dataset/words_dataset/PTS56F/53622e6e6648c2a3c3ac6766_72307.png
# Sb.nfH£ìgf
# sò . n,H£7ù,
# EDIT DISTANCE: 8
#
# Processing:  ../dataset/words_dataset/PTS56F/3c622c48447e426c6467_49036.png
# <b,HD~Bldg
# <ò, H0~8Zdù
# EDIT DISTANCE: 6
#
# Processing:  ../dataset/words_dataset/PTS56F/33394221276a3538452e_78350.png
# 39B!'j58E.
# 3 98 , 75 8E.
# EDIT DISTANCE: 7
#
# Processing:  ../dataset/words_dataset/PTS56F/5d556dc2a34d614e517345_44719.png
# ]Um£MaNQsE
# J 0m £M1N Qs E
# EDIT DISTANCE: 7
#
# Processing:  ../dataset/words_dataset/PTS56F/5c69283a4968562e422d_26390.png
# \i(:IhV.B-
# \Zd.. ,h k 8 -
# EDIT DISTANCE: 11
#
# Processing:  ../dataset/words_dataset/PTS56F/5b794c373053c2b0736a6f_91041.png
# [yL70S°sjo
# Zy [ 70 S Os, 0
# EDIT DISTANCE: 10
#
# Processing:  ../dataset/words_dataset/PTS56F/56c3b9612b21667a475a7e_59626.png
# Vùa+!fzGZ~
# Pù 1 + A Gz~
# EDIT DISTANCE: 8
#
# Processing:  ../dataset/words_dataset/PTS56F/57c2a324343a455be282ac3f20_53642.png
# W£$4:E[€?
# l£ $ 4 .. E,6P
# EDIT DISTANCE: 11
#
# Processing:  ../dataset/words_dataset/PTS56F/2f757d302b5d5b287a6a_93068.png
# /u}0+][(zj
# aJ, 0+jéQ
# EDIT DISTANCE: 9
#
# Processing:  ../dataset/words_dataset/PTS56F/41696e3b6851304c23c3b2_72753.png
# Ain;hQ0L#ò
# @ Zn ,.h Q0[ #ò
# EDIT DISTANCE: 9
#
# Processing:  ../dataset/words_dataset/PTS56F/44382d2f296855663971_58675.png
# D8-/)hUf9q
# 0 8 -d h 0X w
# EDIT DISTANCE: 10
#
# Processing:  ../dataset/words_dataset/PTS56F/754b646f6c202d553f7b_15293.png
# uKdol -U?{
# jKd0Z -0P£
# EDIT DISTANCE: 6
#
# Processing:  ../dataset/words_dataset/PTS56F/692d63543c6b3028537d_84291.png
# i-cT<k0(S}
# Z - c r< k0 #N
# EDIT DISTANCE: 9
#
# Processing:  ../dataset/words_dataset/PTS56F/684d313a232748262467_85518.png
# hM1:#'H&$g
# hMJ ..#,H& $ù
# EDIT DISTANCE: 7
#
# Processing:  ../dataset/words_dataset/PTS56F/456168613175252c4144_80968.png
# Eaha1u%,AD
# E1h1 J j %,@ 0
# EDIT DISTANCE: 10
#
# Processing:  ../dataset/words_dataset/PTS56F/4f3e52442b69462428c3ac_42931.png
# O>RD+iF$(ì
# 0 > R 0 + Z F $ #7
# EDIT DISTANCE: 13
#
# Processing:  ../dataset/words_dataset/PTS56F/c3b237383963685b4d773e_74847.png
# ò789ch[Mw>
# ò 78 9 c h ,M -
# EDIT DISTANCE: 8
#
# Processing:  ../dataset/words_dataset/PTS56F/7d54c3a92cc3acc3a83f663a37_16212.png
# }Té,ìè?f:7
# j ì, 7é,.7
# EDIT DISTANCE: 8
#
# Processing:  ../dataset/words_dataset/PTS56F/6d5d706c6370476f4f28_52902.png
# m]plcpGoO(
# m,@ Z c@ G0 0 #
# EDIT DISTANCE: 12
#
# Processing:  ../dataset/words_dataset/PTS56F/4457396d34c3a82f36764e_99262.png
# DW9m4è/6vN
# 0 l9 m 4 é.6 pN
# EDIT DISTANCE: 10
#
# Processing:  ../dataset/words_dataset/PTS56F/41593072665c7625773a_42803.png
# AY0rf\v%w:
# @ r0 .P% ' ..
# EDIT DISTANCE: 12
#
# Processing:  ../dataset/words_dataset/PTS56F/7b68c2a330265724634336_11161.png
# {h£0&W$cC6
# éh£0& l$cx6
# EDIT DISTANCE: 4
#
# Processing:  ../dataset/words_dataset/PTS56F/3a3e57324c247b3f4661_21641.png
# :>W2L${?Fa
# .. > l2 [ $ £?F1
# EDIT DISTANCE: 11
#
# Processing:  ../dataset/words_dataset/PTS56F/6f3c4f59426331675c54_27747.png
# o<OYBc1g\T
# 0 < 0 r8 C j ù \ r
# EDIT DISTANCE: 16
#
# Processing:  ../dataset/words_dataset/PTS56F/617d5d796d2e432440c2a3_66777.png
# a}]ym.C$@£
# 1,jym . x$ @ £
# EDIT DISTANCE: 8
#
# Processing:  ../dataset/words_dataset/PTS56F/684a53426ac2b05a68c3ac3a_13679.png
# hJSBj°Zhì:
# WJS87 OZh 7 ..
# EDIT DISTANCE: 10
#
# Processing:  ../dataset/words_dataset/PTS56F/4221342965736d4f4b40_85696.png
# B!4)esmOK@
# 8 ,~ esm 0K @
# EDIT DISTANCE: 8
#
# Processing:  ../dataset/words_dataset/PTS56F/26654f69c3a85d3b6c4757_79117.png
# &eOiè];lGW
# & e 0Zé,,.Z G l
# EDIT DISTANCE: 12
#
# Processing:  ../dataset/words_dataset/PTS56F/55c3ac597331c3b24c38686f_43228.png
# UìYs1òL8ho
# 07 WJ ò[ 8h0
# EDIT DISTANCE: 9
#
# Processing:  ../dataset/words_dataset/PTS56F/486f5441c3a95a36703877_49768.png
# HoTAéZ6p8w
# H0 > éZ6@ 8'
# EDIT DISTANCE: 7
#
# Processing:  ../dataset/words_dataset/PTS56F/664c7566534f7448c3a9c3a8_23199.png
# fLufSOtHéè
# ,[ J,s 0 t H é é
# EDIT DISTANCE: 13
#
# Processing:  ../dataset/words_dataset/PTS56F/6c56744a53315a53306e_14473.png
# lVtJS1ZS0n
# Z P5SJ ZS0 n
# EDIT DISTANCE: 7
#
# Processing:  ../dataset/words_dataset/PTS56F/382142386376577a4533_60198.png
# 8!B8cvWzE3
# 8 , 8 8 c p lz E 3
# EDIT DISTANCE: 12
#
# Processing:  ../dataset/words_dataset/PTS56F/352f2f3935656264612d_99168.png
# 5//95ebda-
# 5é9 5 e ò d 1 -
# EDIT DISTANCE: 10
#
# Processing:  ../dataset/words_dataset/PTS56F/6d417a567a4f26362f35_10918.png
# mAzVzO&6/5
# m@ z Pz 0 & 6-5
# EDIT DISTANCE: 9
#
# Processing:  ../dataset/words_dataset/PTS56F/5b213a5658477849e282ac20_11005.png
# [!:VXGxI€
# £ , .. PXG X , €
# EDIT DISTANCE: 13
#
# Processing:  ../dataset/words_dataset/PTS56F/2f214024647746626137_83656.png
# /!@$dwFba7
# d @ $d'Fò 17
# EDIT DISTANCE: 7
#
# Processing:  ../dataset/words_dataset/PTS56F/7e7d615a507a2171c3ac34_60580.png
# ~}aZPz!qì4
# ~, 1zPz ,w 7 4
# EDIT DISTANCE: 10
#
# Processing:  ../dataset/words_dataset/PTS56F/385b29553b2e75783c33_38702.png
# 8[)U;.ux<3
# 82 0,.. jx<3
# EDIT DISTANCE: 7
#
# Processing:  ../dataset/words_dataset/PTS56F/7b6a246353507b575965_62472.png
# {j$cSP{WYe
# é $ csP£ w
# EDIT DISTANCE: 8
#
# Processing:  ../dataset/words_dataset/PT
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/4fc3b9c3a8684b2f2625364c_60353.png
# OùèhK/&%6L
# o ùèh lK,B%6L
# EDIT DISTANCE: 6
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/27494026496d2c6d3641_64672.png
# 'I@&Im,m6A
# ' l @Bl m,m 6A
# EDIT DISTANCE: 7
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/68395727564761426f78_30739.png
# h9W'VGaBox
# h 9W'VGa Box
# EDIT DISTANCE: 2
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/c3ac494c407b2453724e72_99004.png
# ìIL@{$SrNr
# ì l L@{$srNr
# EDIT DISTANCE: 4
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/483e62336d3825707868_15182.png
# H>b3m8%pxh
# H> b3m 8%pxh
# EDIT DISTANCE: 2
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/7d424a3a4e6249483829_54886.png
# }BJ:NbIH8)
# }BJ : N b l H 8)
# EDIT DISTANCE: 7
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/3171314d734b6b20c3a947_98459.png
# 1q1MsKk éG
# 1q1MslK> éG
# EDIT DISTANCE: 2
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/3a407a21645821536632_51210.png
# :@z!dX!Sf2
# : @z ! d x! s f2
# EDIT DISTANCE: 8
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/5b3174702b73204c37c3a9_57921.png
# [1tp+s L7é
# [1zp.s L7é
# EDIT DISTANCE: 2
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/36496852524e6f446b42_54911.png
# 6IhRRNoDkB
# 6l h RRNo D> B
# EDIT DISTANCE: 6
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/2526494553c3ac5b2bc3b240_57155.png
# %&IESì[+ò@
# %Bl Esì [.ò@
# EDIT DISTANCE: 6
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/75454b6b4363242c3052_70722.png
# uEKkCc$,0R
# u E lK>Cc$,O R
# EDIT DISTANCE: 6
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/3f4053c3ac764821553942_11569.png
# ?@SìvH!U9B
# P@sìvH ! U 9 B
# EDIT DISTANCE: 6
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/4f51384e4dc3b229333a6f_40540.png
# OQ8NMò)3:o
# OQ8N Mò)3:o
# EDIT DISTANCE: 1
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/425c596a676745257d52_46101.png
# B\YjggE%}R
# B\YJ g g E %} R
# EDIT DISTANCE: 6
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/5456517a523855505224_34135.png
# TVQzR8UPR$
# WQ z R8 U P R$
# EDIT DISTANCE: 7
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/576a3848595b7a57683b_84473.png
# Wj8HY[zWh;
# WJ 8 H Y[ zWh ;
# EDIT DISTANCE: 6
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/694146c3b253307b334965_79232.png
# iAFòS0{3Ie
# iAFòSO{3 le
# EDIT DISTANCE: 3
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/4d466f746a4156534749_17422.png
# MFotjAVSGI
# M F o zJ AV S G l
# EDIT DISTANCE: 10
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/403e46486e556f6661c3ac_12338.png
# @>FHnUofaì
# @> F H n U o #aì
# EDIT DISTANCE: 7
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/372662736351444dc3a842_73018.png
# 7&bscQDMèB
# 7BbscQ DM è B
# EDIT DISTANCE: 4
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/593965704c5d3ec3ac4e3f_87093.png
# Y9epL]>ìN?
# Y9ep L]>ì N P
# EDIT DISTANCE: 4
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/454c706123634c7a2155_53840.png
# ELpa#cLz!U
# ELpa#cLz! U
# EDIT DISTANCE: 1
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/4971496758643942c2a37e_46212.png
# IqIgXd9B£~
# lq lgXd 9 B£ ~
# EDIT DISTANCE: 6
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/62653a5c3e7e542720c3a9_45434.png
# be:\>~T' é
# be:\>~T' é
# EDIT DISTANCE: 0
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/442e514d77245a4e7663_97250.png
# D.QMw$ZNvc
# D.Q Mw$ZNvc
# EDIT DISTANCE: 1

# %%
results[0]
edit_distances = [result['edit_distance'] for result in results if result['edit_distance'] is not None]
mean = np.mean(edit_distances)
variance = np.var(edit_distances)
minimum = np.min(edit_distances)
maximum = np.max(edit_distances)

print(f"Mean: {mean}, Variance: {variance}, Min: {minimum}, Max: {maximum}")
# Out:
# Mean: 5.43, Variance: 23.099766666666664, Min: 0, Max: 40

# %%
max_edit_distance_objects = [result for result in results if result['edit_distance'] == maximum]
print(max_edit_distance_objects)
# Out:
# [{'path': '../dataset/words_dataset/Lato-Hairline/756e7a6d752351525275_73001.png', 'label': np.str_('unzmu#QRRu'), 'output': 'g... -%.Z .-~.-~. g...# :Z:&.. Z] Z] g...', 'edit_distance': 40}]

# %%
def normalize_simple(text):
    if not text:
        return ""
    text = text.lower().replace(" ", "")
    replacements = {
        '0': 'o',
        'i': 'l',
        '1': 'l',
        'I': 'l',
    }
    return ''.join(replacements.get(c, c) for c in text)

correct_predictions_case = sum(
    1 for result in results
    if result['output'] and result['label'] == result['output']
)

correct_predictions = sum(
    1 for result in results
    if result['output'] and result['label'].lower() == result['output'].lower()
)

correct_predictions_no_spaces = sum(
    1 for result in results 
    if result['output'] and result['label'].replace(" ", "").lower() == result['output'].replace(" ", "").lower()
)

correct_predictions_case_no_spaces = sum(
    1 for result in results
    if result['output'] and result['label'].replace(" ", "") == result['output'].replace(" ", "")
)

correct_predictions_ignore_simple = sum(
    1 for result in results
    if result['output'] and normalize_simple(result['label']) == normalize_simple(result['output'])
)

# Accuracy values
accuracy_case = correct_predictions_case / len(results) * 100
accuracy = correct_predictions / len(results) * 100
accuracy_no_spaces = correct_predictions_no_spaces / len(results) * 100
accuracy_case_no_spaces = correct_predictions_case_no_spaces / len(results) * 100
accuracy_ignore_simple = correct_predictions_ignore_simple / len(results) * 100

# Output
print(f"Accuracy (case sensitive): {accuracy_case:.2f}%")
print(f"Accuracy (case insensitive): {accuracy:.2f}%")
print(f"Accuracy (case insensitive, no spaces): {accuracy_no_spaces:.2f}%")
print(f"Accuracy (case sensitive, no spaces): {accuracy_case_no_spaces:.2f}%")
print(f"Accuracy (ignore case, spaces, o=0, i=l=I=1): {accuracy_ignore_simple:.2f}%")
# Out:
# Accuracy (case sensitive): 2.40%
# Accuracy (case insensitive): 3.60%
# Accuracy (case insensitive, no spaces): 43.80%
# Accuracy (case sensitive, no spaces): 32.20%
# Accuracy (ignore case, spaces, o=0, i=l=I=1): 48.60%

# %%
nonzero_edit_distance = [result for result in results if result['output'] and result['label'] != result['output']]
for r in nonzero_edit_distance:
    print(r)
# Out:
# {'path': '../dataset/words_dataset/Lato-Medium/2e50447b593857e282acc3a924_32221.png', 'label': np.str_('.PD{Y8W€é$'), 'output': '. P D{Y8W€é$', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/76774e634770415c666b_81035.png', 'label': np.str_('vwNcGpA\\fk'), 'output': 'vw N cG pA\\&', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Lato-Medium/577b32352bc3b9762b4437_74553.png', 'label': np.str_('W{25+ùv+D7'), 'output': 'W{2 5 + ùV+ D 7', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/Lato-Medium/536c2e68504d41446d2c_78218.png', 'label': np.str_('Sl.hPMADm,'), 'output': 'Sl. h PMADm,', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/61753a44245d375d7578_51301.png', 'label': np.str_('au:D$]7]ux'), 'output': 'a u: D$]7] ux', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Lato-Medium/4f3b513b704d29213577_91954.png', 'label': np.str_('O;Q;pM)!5w'), 'output': 'o;Q; pM)! 5W', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Lato-Medium/34524e47462b34652952_55796.png', 'label': np.str_('4RNGF+4e)R'), 'output': '4 RN G F+4e) R', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Lato-Medium/75455034576f726c6cc3b9_42634.png', 'label': np.str_('uEP4Worllù'), 'output': 'u E P4Wo r l l ù', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/Lato-Medium/4b7a582e355c4d633e5b_76218.png', 'label': np.str_('KzX.5\\Mc>['), 'output': 'KzX. 5 \\ M c > [', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/Lato-Medium/7673753134782c6f7a72_80068.png', 'label': np.str_('vsu14x,ozr'), 'output': 'vsu 14x,ozr', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/56705353563b6225c2a350_53779.png', 'label': np.str_('VpSSV;b%£P'), 'output': 'VpSSV; b%£ P', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/6b552c51792c6e324449_49559.png', 'label': np.str_('kU,Qy,n2DI'), 'output': 'kU,Qy,n2 D l', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Lato-Medium/693a54543f485c5b4158_75665.png', 'label': np.str_('i:TT?H\\[AX'), 'output': 'i :TT? H \\ [AX', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Lato-Medium/71696a524d4b212664c2a3_15651.png', 'label': np.str_('qijRMK!&d£'), 'output': 'qiJ RM K!&d£', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Lato-Medium/59684f5c3f3f3e52c3b276_63183.png', 'label': np.str_('YhO\\??>Ròv'), 'output': 'YhO\\?? > Ròv', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/7e56613a51497d4c407b_28146.png', 'label': np.str_('~Va:QI}L@{'), 'output': '~Va : Q l } L@ {', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/Lato-Medium/77c2b032573f5b6f552b33_81701.png', 'label': np.str_('w°2W?[oU+3'), 'output': 'W°2W? [oU + 3', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Lato-Medium/574cc3a9383cc3b27923572b_81289.png', 'label': np.str_('WLé8<òy#W+'), 'output': 'WLé8 < òy#W+', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/4a3fc2b03a53543a4e2d67_84362.png', 'label': np.str_('J?°:ST:N-g'), 'output': 'J?°:ST: N -g', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/615b614b54622d595c6e_71894.png', 'label': np.str_('a[aKTb-Y\\n'), 'output': 'a [a KTb-Y\\n', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/7e7dc3a82726616c6131c3b9_74861.png', 'label': np.str_("~}è'&ala1ù"), 'output': "~}è'&a la 1 ù", 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Lato-Medium/63314b797838725765e282ac_68186.png', 'label': np.str_('c1Kyx8rWe€'), 'output': 'c1 Kyx8 rWe€', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/6d635426332e587d7036_16506.png', 'label': np.str_('mcT&3.X}p6'), 'output': 'm cT & 3 . X } p 6', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/Lato-Medium/4323547a75794fc3b2c2b035_98857.png', 'label': np.str_('C#TzuyOò°5'), 'output': 'c # Tz u y o ò ° 5', 'edit_distance': 10}
# {'path': '../dataset/words_dataset/Lato-Medium/5d6124754f7146532974_85687.png', 'label': np.str_(']a$uOqFS)t'), 'output': ']a$uoq FS)t', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/5d697b5d7926c3a8504842_98728.png', 'label': np.str_(']i{]y&èPHB'), 'output': ']i{]y&èPH B', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/517262377ac3a9374d544c_61780.png', 'label': np.str_('Qrb7zé7MTL'), 'output': 'Qrb7zé7 M TL', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/4a51c3b96775296b33586d_93586.png', 'label': np.str_('JQùgu)k3Xm'), 'output': 'JQùgu)K3Xm', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/773a7a755167c3a8c3b2387e_33044.png', 'label': np.str_('w:zuQgèò8~'), 'output': 'W :z u Qgèò 8 ~', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/Lato-Medium/294e24716f4a23687269_19443.png', 'label': np.str_(')N$qoJ#hri'), 'output': ') N $ qoJ#h ri', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Lato-Medium/7754372534c3b256494358_98772.png', 'label': np.str_('wT7%4òVICX'), 'output': 'wT 7 % 4 òV l CX', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/Lato-Medium/27597b2b3e574c454964_26319.png', 'label': np.str_("'Y{+>WLEId"), 'output': "'Y{+ >W LE l d", 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Lato-Medium/746242c3a958404c405a76_13230.png', 'label': np.str_('tbBéX@L@Zv'), 'output': 'tb B éX@ L@Zv', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Lato-Medium/4f286d7e5962446cc3b967_84230.png', 'label': np.str_('O(m~YbDlùg'), 'output': 'o(m ~Yb D l ùg', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Lato-Medium/6647397d3b2e252f5621_89680.png', 'label': np.str_('fG9};.%/V!'), 'output': 'fG9}; .%,V!', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/277753e282acc3ac3a6f3b202e_31570.png', 'label': np.str_("'wS€ì:o; ."), 'output': "'WS€ì:o; .", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/5271252f4143c3a8c2a33257_51859.png', 'label': np.str_('Rq%/ACè£2W'), 'output': 'Rq % ,A C è £ 2 W', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/Lato-Medium/41734e43673927736727_69552.png', 'label': np.str_("AsNCg9'sg'"), 'output': "As N Cg9 'sg'", 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Lato-Medium/62234be282ac235c256e2b57_76992.png', 'label': np.str_('b#K€#\\%n+W'), 'output': 'b# K€#\\% n+W', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/77622b506e5a332c6b27_56508.png', 'label': np.str_("wb+PnZ3,k'"), 'output': "wb+ PnZ3, K'", 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Lato-Medium/587d3a3e7667c3b2533b6a_86257.png', 'label': np.str_('X}:>vgòS;j'), 'output': 'X}: >VgòS ;j', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Lato-Medium/4f512332573040274a38_78797.png', 'label': np.str_("OQ#2W0@'J8"), 'output': "O Q#2W0@ 'J 8", 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Lato-Medium/45483321234578262332_81667.png', 'label': np.str_('EH3!#Ex&#2'), 'output': 'E H 3 !# Ex&#2', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Lato-Medium/5847534a75683f6e6832_30564.png', 'label': np.str_('XGSJuh?nh2'), 'output': 'XGSJ u h? n h2', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Lato-Medium/4c487b69645b587bc3a96f_33349.png', 'label': np.str_('LH{id[X{éo'), 'output': 'LH {i d [X{éo', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Lato-Medium/28732b20754a6ec3b93676_90122.png', 'label': np.str_('(s+ uJnù6v'), 'output': '(s+ uJnù6V', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/4054c3b96d727443614527_95995.png', 'label': np.str_("@TùmrtCaE'"), 'output': "@Tù m rtca E '", 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Lato-Medium/234838e282ac3147283a26c3b9_68700.png', 'label': np.str_('#H8€1G(:&ù'), 'output': '#H 8€1G(:&ù', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/5d6e5557352f79535770_35331.png', 'label': np.str_(']nUW5/ySWp'), 'output': '] nU W5,ySWp', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Lato-Medium/3959503654335b484e72_95734.png', 'label': np.str_('9YP6T3[HNr'), 'output': '9YP6T3 [ H N r', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Lato-Medium/7d352169c3a86b5066256f_13759.png', 'label': np.str_('}5!ièkPf%o'), 'output': '}5 ! iè kPf% o', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Lato-Medium/c3b257c3a82f552e74685179_10304.png', 'label': np.str_('òWè/U.thQy'), 'output': 'òWè, U . th Qy', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Lato-Medium/6d594747357e3e2b4d6b_15899.png', 'label': np.str_('mYGG5~>+Mk'), 'output': 'mYG G 5 ~ > + M K', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/Lato-Medium/57c3b93b5b737878355b6d_51217.png', 'label': np.str_('Wù;[sxx5[m'), 'output': 'Wù ; [sXX5 [m', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Lato-Medium/28574b6169796f27686d_54746.png', 'label': np.str_("(WKaiyo'hm"), 'output': "(WKa iyo' h m", 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Lato-Medium/4457383c66c3a955c2a35d5a_20866.png', 'label': np.str_('DW8<féU£]Z'), 'output': 'DW8 < féU £]Z', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Lato-Medium/4fc2a3455c32616f7a4c2d_79853.png', 'label': np.str_('O£E\\2aozL-'), 'output': 'o£ E \\2a oz L-', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Lato-Medium/2ec3ac496470c3b257763c3e_51118.png', 'label': np.str_('.ìIdpòWv<>'), 'output': '.ìldpòWV< >', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Lato-Medium/61547738503a486e2d64_90295.png', 'label': np.str_('aTw8P:Hn-d'), 'output': 'amw8 P : H n - d', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/Lato-Medium/3c6d5637262741455c3c_64807.png', 'label': np.str_("<mV7&'AE\\<"), 'output': "< mV7&'AE\\ <", 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/216123743128c3ace282acc3a94f_10347.png', 'label': np.str_('!a#t1(ì€éO'), 'output': '!a#t1 (ì€éo', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/6a305577682726c2b0326b_30898.png', 'label': np.str_("j0Uwh'&°2k"), 'output': "J0U wh '&°2 K", 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Lato-Medium/34c3b2295a687028343932_60298.png', 'label': np.str_('4ò)Zhp(492'), 'output': '4ò)Z h p (49 2', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Lato-Medium/59762d4d74246878677a_66236.png', 'label': np.str_('Yv-Mt$hxgz'), 'output': 'Yv - Mt$ hxgz', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Lato-Medium/584f74214f404d31393b_62893.png', 'label': np.str_('XOt!O@M19;'), 'output': 'XOt!O@ M 1 9 ;', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Lato-Medium/757166235b6e684d3be282ac_77518.png', 'label': np.str_('uqf#[nhM;€'), 'output': 'uqf# [n h M ;€', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Lato-Medium/34406e267250675c2424_90378.png', 'label': np.str_('4@n&rPg\\$$'), 'output': '4@ n & r Pg\\$ $', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Lato-Medium/6a6c655c7d694e3e316d_61599.png', 'label': np.str_('jle\\}iN>1m'), 'output': 'Jle\\}iN >1m', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/3f3c6361652e61423865_84147.png', 'label': np.str_('?<cae.aB8e'), 'output': '?< cae.a B8e', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/424e272b712464787327_89938.png', 'label': np.str_("BN'+q$dxs'"), 'output': "BN '+q$dxs'", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/357848626326775a6b4d_57001.png', 'label': np.str_('5xHbc&wZkM'), 'output': '5x H bc&wZK M', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Lato-Medium/4b3c4455386a72293421_41233.png', 'label': np.str_('K<DU8jr)4!'), 'output': 'K< D U8jr)4!', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/2c2746c3b93f79717e3e66_66366.png', 'label': np.str_(",'Fù?yq~>f"), 'output': ",' Fù?yq~ >f", 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/45743966c3a82f5a5a234d_42343.png', 'label': np.str_('Et9fè/ZZ#M'), 'output': 'Et9fè ,ZZ# M', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Lato-Medium/5dc3b926414a52465952c2b0_59852.png', 'label': np.str_(']ù&AJRFYR°'), 'output': '] ù&AJ RFYR°', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/c3ac68687a506f4ec3b25a77_12657.png', 'label': np.str_('ìhhzPoNòZw'), 'output': 'ì h hz Po N òZW', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/Lato-Medium/e282ac465071362f23c3a93f64_16572.png', 'label': np.str_('€FPq6/#é?d'), 'output': '€ F Pq 6,#é?d', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Lato-Medium/50c3b951217d4d482d2b34_30604.png', 'label': np.str_('PùQ!}MH-+4'), 'output': 'PùQ!}M H -+4', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/39614042c3b95427412f3b_86736.png', 'label': np.str_("9a@BùT'A/;"), 'output': "9a @ B ùT 'A, ;", 'edit_distance': 6}
# {'path': '../dataset/words_dataset/Lato-Medium/76303a502c3b413f2f6a_31353.png', 'label': np.str_('v0:P,;A?/j'), 'output': 'v0 : P, ;A? ,J', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/Lato-Medium/34264f6d67654b4e4e33_34887.png', 'label': np.str_('4&OmgeKNN3'), 'output': '4&OmgeKN N3', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/623f43406a4e40c2a34a65_99907.png', 'label': np.str_('b?C@jN@£Je'), 'output': 'b?C@J N @£J e', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Lato-Medium/6824356b713c747a3063_95556.png', 'label': np.str_('h$5kq<tz0c'), 'output': 'h$ 5 Kq < tz0c', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Lato-Medium/713c29274c62c3ac5a654e_34725.png', 'label': np.str_("q<)'LbìZeN"), 'output': "q< )' LbìZeN", 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/33764b4b46733c774e20_73678.png', 'label': np.str_('3vKKFs<wN '), 'output': '3v KK Fs< w N', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Lato-Medium/c3ac597170354a275a6e39_35453.png', 'label': np.str_("ìYqp5J'Zn9"), 'output': "ì Yq p 5 J ' Z n 9", 'edit_distance': 8}
# {'path': '../dataset/words_dataset/Lato-Medium/4b613f59703c3e4d4b4f_11410.png', 'label': np.str_('Ka?Yp<>MKO'), 'output': 'Ka?Yp< > M KO', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Lato-Medium/6849474f3521206ac3ac55_51173.png', 'label': np.str_('hIGO5! jìU'), 'output': 'hlGO5! JìU', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/5c567a67342658c3b9776a_84274.png', 'label': np.str_('\\Vzg4&Xùwj'), 'output': '\\Vz g 4 & X ù Wj', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/Lato-Medium/35c3a9653bc3b94b6c6d6120_96272.png', 'label': np.str_('5ée;ùKlma '), 'output': '5ée;ù Kl ma', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Lato-Medium/757b3630452369716831_35864.png', 'label': np.str_('u{60E#iqh1'), 'output': 'u{60E#iq h1', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/6878444d78476f4a535a_55815.png', 'label': np.str_('hxDMxGoJSZ'), 'output': 'hx D M xGoJ SZ', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Lato-Medium/c2b0e282ac624e4653c3a8792732_84677.png', 'label': np.str_("°€bNFSèy'2"), 'output': "°€bN FSèy'2", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/c2a343452778453843695b_48348.png', 'label': np.str_("£CE'xE8Ci["), 'output': "£cE'XE8ci [", 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/213132c3ac584b5244c3b237_42945.png', 'label': np.str_('!12ìXKRDò7'), 'output': ',J 2 7XKR 0ò 7', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS56F/29494620584a2863782b_58659.png', 'label': np.str_(')IF XJ(cx+'), 'output': 'J , F X7écX+', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/6e4441746c6b5545c3a97b_21018.png', 'label': np.str_('nDAtlkUEé{'), 'output': 'n 0q tZ K 0Eé £', 'edit_distance': 11}
# {'path': '../dataset/words_dataset/PTS56F/5d64235831593f536271_89142.png', 'label': np.str_(']d#X1Y?Sbq'), 'output': 'Jd#XJ rPSòw', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/48c2b06ac3ac52235a622e31_96798.png', 'label': np.str_('H°jìR#Zb.1'), 'output': 'H 17R #eò. J', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS56F/657147317b565a685575_35562.png', 'label': np.str_('eqG1{VZhUu'), 'output': 'e w G J mZh 0 j', 'edit_distance': 11}
# {'path': '../dataset/words_dataset/PTS56F/c3ac3a34762c4370657756_34324.png', 'label': np.str_('ì:4v,CpewV'), 'output': "7 .. 4 k X@ e ' P", 'edit_distance': 15}
# {'path': '../dataset/words_dataset/PTS56F/243e6b4f3f6a4632c2a357_19402.png', 'label': np.str_('$>kO?jF2£W'), 'output': '$ > k 0 òF2 £ l', 'edit_distance': 9}
# {'path': '../dataset/words_dataset/PTS56F/4040406f3c36344a7164_74321.png', 'label': np.str_('@@@o<64Jqd'), 'output': '@ @ @ 0<64jwd', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS56F/615bc2b0574d297b7b346a_41116.png', 'label': np.str_('a[°WM){{4j'), 'output': '1£ o lN £é~', 'edit_distance': 11}
# {'path': '../dataset/words_dataset/PTS56F/452441213e75507d686d_16782.png', 'label': np.str_('E$A!>uP}hm'), 'output': 'E$@ ,> j~ hm', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/23302e687a634f717178_73932.png', 'label': np.str_('#0.hzcOqqx'), 'output': '#0. hzc0wwX', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/3462777323204a523a3c_16071.png', 'label': np.str_('4bws# JR:<'), 'output': "4ò's# JR ..<", 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/26c2a334453f3637274631_87283.png', 'label': np.str_("&£4E?67'F1"), 'output': '& £4EP67,FJ', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/62455dc3a97929355a4de282ac_29748.png', 'label': np.str_('bE]éy)5ZM€'), 'output': 'ò E7 éM 5zM€', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/e282ac2c38c3a92e3238736cc3a9_62090.png', 'label': np.str_('€,8é.28slé'), 'output': '€ 8é.2 8SZé', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/313424693c5c63307227_78690.png', 'label': np.str_("14$i<\\c0r'"), 'output': 'J 4$Z<\\c0r,', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/206121484f5163776f56_45609.png', 'label': np.str_(' a!HOQcwoV'), 'output': "1 ,H0QC'0 p", 'edit_distance': 9}
# {'path': '../dataset/words_dataset/PTS56F/4f3e657263525558544d_28245.png', 'label': np.str_('O>ercRUXTM'), 'output': '0 > e rc R 0XrM', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS56F/6732c2a3356c2944427438_19911.png', 'label': np.str_('g2£5l)DBt8'), 'output': 'ù 2 £5 Z2 08 t8', 'edit_distance': 10}
# {'path': '../dataset/words_dataset/PTS56F/6b34383c444f56783261_12708.png', 'label': np.str_('k48<DOVx2a'), 'output': 'K 4 8 < 0 0 Px 2 1', 'edit_distance': 13}
# {'path': '../dataset/words_dataset/PTS56F/c3a84e434269c3a978613674_86405.png', 'label': np.str_('èNCBiéxa6t'), 'output': 'é N x8 Z éX1 6 t', 'edit_distance': 12}
# {'path': '../dataset/words_dataset/PTS56F/7d2c33323121637a7546_68037.png', 'label': np.str_('},321!czuF'), 'output': 'j, 32J ,czJF', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS56F/2b352f6e2d4665782b40_97986.png', 'label': np.str_('+5/n-Fex+@'), 'output': '+ 5an - 8eX+ @', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/6a4f4d39415c48292c7e_48270.png', 'label': np.str_('jOM9A\\H),~'), 'output': 'J 0 M 9q \\H2 , ~', 'edit_distance': 10}
# {'path': '../dataset/words_dataset/PTS56F/c3a968613a793151343b36_21187.png', 'label': np.str_('éha:y1Q4;6'), 'output': 'éh1 ..yJ Q4,.6', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS56F/615d547127716c754f40_46293.png', 'label': np.str_("a]Tq'qluO@"), 'output': '1, M ,W z J 0 @', 'edit_distance': 14}
# {'path': '../dataset/words_dataset/PTS56F/61745a6d3a246a5745c3a8_89186.png', 'label': np.str_('atZm:$jWEè'), 'output': '1 tem .. & lEé', 'edit_distance': 11}
# {'path': '../dataset/words_dataset/PTS56F/31302d716d315a425c25_90698.png', 'label': np.str_('10-qm1ZB\\%'), 'output': 'J 0-wm J Z8\\%', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/7a4b633f71343c395638_38719.png', 'label': np.str_('zKc?q4<9V8'), 'output': 'z Kc Pw 4 < 9 P8', 'edit_distance': 9}
# {'path': '../dataset/words_dataset/PTS56F/5c317867293c54687449_40764.png', 'label': np.str_('\\1xg)<ThtI'), 'output': '\\J Xù, < rh t ,', 'edit_distance': 11}
# {'path': '../dataset/words_dataset/PTS56F/c2b069316dc3ac686f587851_57189.png', 'label': np.str_('°i1mìhoXxQ'), 'output': 'O Z J m 7 h 0Xx Q', 'edit_distance': 12}
# {'path': '../dataset/words_dataset/PTS56F/5b4d503b705c4b7a6e30_49196.png', 'label': np.str_('[MP;p\\Kzn0'), 'output': 'éMP,.@ \\Kz n 0', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/435231c3a8c2b07a3566456d_87704.png', 'label': np.str_('CR1è°z5fEm'), 'output': 'XR J é Oz 5,Em', 'edit_distance': 9}
# {'path': '../dataset/words_dataset/PTS56F/383864557a44c2b067e282ac4d_51432.png', 'label': np.str_('88dUzD°g€M'), 'output': '88d0z0 Où€M', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/4f6fc2a33ec3b27537516179_69300.png', 'label': np.str_('Oo£>òu7Qay'), 'output': '00 £>ò j 7Q1y', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/337d2564c3b925c3b24f6147_99870.png', 'label': np.str_('3}%dù%òOaG'), 'output': '3J % d ù % ò 0 1 G', 'edit_distance': 11}
# {'path': '../dataset/words_dataset/PTS56F/69c3a8397e6133305b52c3ac_31705.png', 'label': np.str_('iè9~a30[Rì'), 'output': 'Zé 9~130éR7', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS56F/c3a953e282ac3b63307679c3b92f_65800.png', 'label': np.str_('éS€;c0vyù/'), 'output': 'é s€,.c 0 Py ùZ', 'edit_distance': 9}
# {'path': '../dataset/words_dataset/PTS56F/2552463bc3b9c3b25b2f7530_33312.png', 'label': np.str_('%RF;ùò[/u0'), 'output': '% R F,. ù ò -J 0', 'edit_distance': 10}
# {'path': '../dataset/words_dataset/PTS56F/7b6b4f5865c3ac5c6c4d26_20353.png', 'label': np.str_('{kOXeì\\lM&'), 'output': 'ék 0Xe 7 \\Z M &', 'edit_distance': 9}
# {'path': '../dataset/words_dataset/PTS56F/2c504b537a2c556e632e_41502.png', 'label': np.str_(',PKSz,Unc.'), 'output': ', PKsz, 0nc.', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/c3a9755362505940c3a85a5a_90728.png', 'label': np.str_('éuSbPY@èZZ'), 'output': 'é J s ò P r @ éez', 'edit_distance': 14}
# {'path': '../dataset/words_dataset/PTS56F/556b53247a7a4356542d_43421.png', 'label': np.str_('UkS$zzCVT-'), 'output': '0KS$zz X#', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS56F/c2a3724bc2a359493c433527_23332.png', 'label': np.str_("£rK£YI<C5'"), 'output': '£rK£ r, < x5 ,', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS56F/46c3b94e49393b45c2a34b28_26379.png', 'label': np.str_('FùNI9;E£K('), 'output': 'Fù N , 9 ,.E£K#', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS56F/4c2b5c36714f66634371_68869.png', 'label': np.str_('L+\\6qOfcCq'), 'output': '[ + \\ 6 w 0yc Gw', 'edit_distance': 12}
# {'path': '../dataset/words_dataset/PTS56F/305c4b332b236f752e6c_38742.png', 'label': np.str_('0\\K3+#ou.l'), 'output': '0\\K3+ #0 j. Z', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS56F/c2a33e6b622b494959645b_30161.png', 'label': np.str_('£>kb+IIYd['), 'output': '£ > kò + , , Md£', 'edit_distance': 11}
# {'path': '../dataset/words_dataset/PTS56F/7e78567d58313e5a4a5d_45261.png', 'label': np.str_('~xV}X1>ZJ]'), 'output': '~X KXJ >47', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS56F/7834722956206578c3b97e_90121.png', 'label': np.str_('x4r)V exù~'), 'output': 'x4# P exù~', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/28316a43764038293525_53062.png', 'label': np.str_('(1jCv@8)5%'), 'output': '<]j cP @ 82 5 %', 'edit_distance': 10}
# {'path': '../dataset/words_dataset/PTS56F/5329745c694f59c3a95a7a_53743.png', 'label': np.str_('S)t\\iOYéZz'), 'output': 'N t\\Z 0 Méez', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS56F/4a2351c3a857c3a9e282ac453168_87946.png', 'label': np.str_('J#QèWé€E1h'), 'output': 'j # Q é lé€E J h', 'edit_distance': 10}
# {'path': '../dataset/words_dataset/PTS56F/74c2b0326c2b5662542e69_41531.png', 'label': np.str_('t°2l+VbT.i'), 'output': 't o2z+ pò £z', 'edit_distance': 9}
# {'path': '../dataset/words_dataset/PTS56F/212b33c3b279682c437338_42715.png', 'label': np.str_('!+3òyh,Cs8'), 'output': ',+ 3 òyh, GS 8', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/c3b25570207a5a52543677_77146.png', 'label': np.str_('òUp zZRT6w'), 'output': "ò0@ zzRr6'", 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/6f23346454733b41785b_19891.png', 'label': np.str_('o#4dTs;Ax['), 'output': '0 # 4 d a ,q X£', 'edit_distance': 12}
# {'path': '../dataset/words_dataset/PTS56F/3578786858c3a874403b5a_75715.png', 'label': np.str_('5xxhXèt@;Z'), 'output': '5xx hXé t @ ,.e', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS56F/437d5a4c4c637a6134c3ac_39380.png', 'label': np.str_('C}ZLLcza4ì'), 'output': 'g z[ [ CZ1 47', 'edit_distance': 12}
# {'path': '../dataset/words_dataset/PTS56F/53622e6e6648c2a3c3ac6766_72307.png', 'label': np.str_('Sb.nfH£ìgf'), 'output': 'sò . n,H£7ù,', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS56F/3c622c48447e426c6467_49036.png', 'label': np.str_('<b,HD~Bldg'), 'output': '<ò, H0~8Zdù', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS56F/33394221276a3538452e_78350.png', 'label': np.str_("39B!'j58E."), 'output': '3 98 , 75 8E.', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/5d556dc2a34d614e517345_44719.png', 'label': np.str_(']Um£MaNQsE'), 'output': 'J 0m £M1N Qs E', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/5c69283a4968562e422d_26390.png', 'label': np.str_('\\i(:IhV.B-'), 'output': '\\Zd.. ,h k 8 -', 'edit_distance': 11}
# {'path': '../dataset/words_dataset/PTS56F/5b794c373053c2b0736a6f_91041.png', 'label': np.str_('[yL70S°sjo'), 'output': 'Zy [ 70 S Os, 0', 'edit_distance': 10}
# {'path': '../dataset/words_dataset/PTS56F/56c3b9612b21667a475a7e_59626.png', 'label': np.str_('Vùa+!fzGZ~'), 'output': 'Pù 1 + A Gz~', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS56F/57c2a324343a455be282ac3f20_53642.png', 'label': np.str_('W£$4:E[€? '), 'output': 'l£ $ 4 .. E,6P', 'edit_distance': 11}
# {'path': '../dataset/words_dataset/PTS56F/2f757d302b5d5b287a6a_93068.png', 'label': np.str_('/u}0+][(zj'), 'output': 'aJ, 0+jéQ', 'edit_distance': 9}
# {'path': '../dataset/words_dataset/PTS56F/41696e3b6851304c23c3b2_72753.png', 'label': np.str_('Ain;hQ0L#ò'), 'output': '@ Zn ,.h Q0[ #ò', 'edit_distance': 9}
# {'path': '../dataset/words_dataset/PTS56F/44382d2f296855663971_58675.png', 'label': np.str_('D8-/)hUf9q'), 'output': '0 8 -d h 0X w', 'edit_distance': 10}
# {'path': '../dataset/words_dataset/PTS56F/754b646f6c202d553f7b_15293.png', 'label': np.str_('uKdol -U?{'), 'output': 'jKd0Z -0P£', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS56F/692d63543c6b3028537d_84291.png', 'label': np.str_('i-cT<k0(S}'), 'output': 'Z - c r< k0 #N', 'edit_distance': 9}
# {'path': '../dataset/words_dataset/PTS56F/684d313a232748262467_85518.png', 'label': np.str_("hM1:#'H&$g"), 'output': 'hMJ ..#,H& $ù', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/456168613175252c4144_80968.png', 'label': np.str_('Eaha1u%,AD'), 'output': 'E1h1 J j %,@ 0', 'edit_distance': 10}
# {'path': '../dataset/words_dataset/PTS56F/4f3e52442b69462428c3ac_42931.png', 'label': np.str_('O>RD+iF$(ì'), 'output': '0 > R 0 + Z F $ #7', 'edit_distance': 13}
# {'path': '../dataset/words_dataset/PTS56F/c3b237383963685b4d773e_74847.png', 'label': np.str_('ò789ch[Mw>'), 'output': 'ò 78 9 c h ,M -', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS56F/7d54c3a92cc3acc3a83f663a37_16212.png', 'label': np.str_('}Té,ìè?f:7'), 'output': 'j ì, 7é,.7', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS56F/6d5d706c6370476f4f28_52902.png', 'label': np.str_('m]plcpGoO('), 'output': 'm,@ Z c@ G0 0 #', 'edit_distance': 12}
# {'path': '../dataset/words_dataset/PTS56F/4457396d34c3a82f36764e_99262.png', 'label': np.str_('DW9m4è/6vN'), 'output': '0 l9 m 4 é.6 pN', 'edit_distance': 10}
# {'path': '../dataset/words_dataset/PTS56F/41593072665c7625773a_42803.png', 'label': np.str_('AY0rf\\v%w:'), 'output': "@ r0 .P% ' ..", 'edit_distance': 12}
# {'path': '../dataset/words_dataset/PTS56F/7b68c2a330265724634336_11161.png', 'label': np.str_('{h£0&W$cC6'), 'output': 'éh£0& l$cx6', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/3a3e57324c247b3f4661_21641.png', 'label': np.str_(':>W2L${?Fa'), 'output': '.. > l2 [ $ £?F1', 'edit_distance': 11}
# {'path': '../dataset/words_dataset/PTS56F/6f3c4f59426331675c54_27747.png', 'label': np.str_('o<OYBc1g\\T'), 'output': '0 < 0 r8 C j ù \\ r', 'edit_distance': 16}
# {'path': '../dataset/words_dataset/PTS56F/617d5d796d2e432440c2a3_66777.png', 'label': np.str_('a}]ym.C$@£'), 'output': '1,jym . x$ @ £', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS56F/684a53426ac2b05a68c3ac3a_13679.png', 'label': np.str_('hJSBj°Zhì:'), 'output': 'WJS87 OZh 7 ..', 'edit_distance': 10}
# {'path': '../dataset/words_dataset/PTS56F/4221342965736d4f4b40_85696.png', 'label': np.str_('B!4)esmOK@'), 'output': '8 ,~ esm 0K @', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS56F/26654f69c3a85d3b6c4757_79117.png', 'label': np.str_('&eOiè];lGW'), 'output': '& e 0Zé,,.Z G l', 'edit_distance': 12}
# {'path': '../dataset/words_dataset/PTS56F/55c3ac597331c3b24c38686f_43228.png', 'label': np.str_('UìYs1òL8ho'), 'output': '07 WJ ò[ 8h0', 'edit_distance': 9}
# {'path': '../dataset/words_dataset/PTS56F/486f5441c3a95a36703877_49768.png', 'label': np.str_('HoTAéZ6p8w'), 'output': "H0 > éZ6@ 8'", 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/664c7566534f7448c3a9c3a8_23199.png', 'label': np.str_('fLufSOtHéè'), 'output': ',[ J,s 0 t H é é', 'edit_distance': 13}
# {'path': '../dataset/words_dataset/PTS56F/6c56744a53315a53306e_14473.png', 'label': np.str_('lVtJS1ZS0n'), 'output': 'Z P5SJ ZS0 n', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/382142386376577a4533_60198.png', 'label': np.str_('8!B8cvWzE3'), 'output': '8 , 8 8 c p lz E 3', 'edit_distance': 12}
# {'path': '../dataset/words_dataset/PTS56F/352f2f3935656264612d_99168.png', 'label': np.str_('5//95ebda-'), 'output': '5é9 5 e ò d 1 -', 'edit_distance': 10}
# {'path': '../dataset/words_dataset/PTS56F/6d417a567a4f26362f35_10918.png', 'label': np.str_('mAzVzO&6/5'), 'output': 'm@ z Pz 0 & 6-5', 'edit_distance': 9}
# {'path': '../dataset/words_dataset/PTS56F/5b213a5658477849e282ac20_11005.png', 'label': np.str_('[!:VXGxI€ '), 'output': '£ , .. PXG X , €', 'edit_distance': 13}
# {'path': '../dataset/words_dataset/PTS56F/2f214024647746626137_83656.png', 'label': np.str_('/!@$dwFba7'), 'output': "d @ $d'Fò 17", 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/7e7d615a507a2171c3ac34_60580.png', 'label': np.str_('~}aZPz!qì4'), 'output': '~, 1zPz ,w 7 4', 'edit_distance': 10}
# {'path': '../dataset/words_dataset/PTS56F/385b29553b2e75783c33_38702.png', 'label': np.str_('8[)U;.ux<3'), 'output': '82 0,.. jx<3', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/7b6a246353507b575965_62472.png', 'label': np.str_('{j$cSP{WYe'), 'output': 'é $ csP£ w', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS55F/7a71253779517b537759_15112.png', 'label': np.str_('zq%7yQ{SwY'), 'output': 'zq % 7yQ{SwY', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/6d443141304e2b2b50c3a9_25410.png', 'label': np.str_('mD1A0N++Pé'), 'output': 'm D 1A0 N ++ Pé', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS55F/696843265153486b2c39_79436.png', 'label': np.str_('ihC&QSHk,9'), 'output': 'J h C & QS H K,9', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS55F/7843386c67543c6b583a_43030.png', 'label': np.str_('xC8lgT<kX:'), 'output': 'xC8 lgT<KX :', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/4c2561656f3268766f6c_54921.png', 'label': np.str_('L%aeo2hvol'), 'output': 'L%aeo2 hvo l', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/68c3a9644d67572f707d5d_57346.png', 'label': np.str_('hédMgW/p}]'), 'output': 'h é d M g W,p }]', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS55F/6651684e472c3324763f_52527.png', 'label': np.str_('fQhNG,3$v?'), 'output': 'fQh N G , S $v?', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS55F/214d46713b554d7d3030_11547.png', 'label': np.str_('!MFq;UM}00'), 'output': '!MFq ;UM}00', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/416c7234524453644f34_73165.png', 'label': np.str_('Alr4RDSdO4'), 'output': 'Alr4R DS dO4', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/6a31c2b0c3b25466417d6244_88403.png', 'label': np.str_('j1°òTfA}bD'), 'output': 'J 1 °òTfA} b D', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS55F/7e714e547d20e282ac32c2a326_40568.png', 'label': np.str_('~qNT} €2£&'), 'output': '~qNT} é2£&', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/6ec3ac473844e282ac54337364_45537.png', 'label': np.str_('nìG8D€T3sd'), 'output': 'nì G 8 DéT Ssd', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS55F/4865c3a9c3ac5a297e39723c_81498.png', 'label': np.str_('HeéìZ)~9r<'), 'output': 'H eéì Z)~9 r<', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/c3a83ae282ac3144c3a82d28404a_57437.png', 'label': np.str_('è:€1Dè-(@J'), 'output': 'è:é1 Dè-(@J', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/507b612832c2b04c6d5b34_93288.png', 'label': np.str_('P{a(2°Lm[4'), 'output': 'P{a(2 °Lm[4', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/37c2b0707a2b3a7dc3a87774_54087.png', 'label': np.str_('7°pz+:}èwt'), 'output': '7 °pz+ :}èwt', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/2bc3b94c676e3026786253_63714.png', 'label': np.str_('+ùLgn0&xbS'), 'output': '+ ù Lg n 0 & X bS', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS55F/59542150263328713173_68970.png', 'label': np.str_('YT!P&3(q1s'), 'output': 'YT ! P & S (q 1 s', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS55F/c3b93e3772652f39235c30_21016.png', 'label': np.str_('ù>7re/9#\\0'), 'output': 'ù > 7 re,9 #\\0', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS55F/6f2d486147496a463bc3b9_61808.png', 'label': np.str_('o-HaGIjF;ù'), 'output': "o- HaG'j F;ù", 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/6cc2a3345375565d594753_31852.png', 'label': np.str_('l£4SuV]YGS'), 'output': 'l£4S uV]YG S', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/462e32553023597dc2a32c_44847.png', 'label': np.str_('F.2U0#Y}£,'), 'output': 'F.2 U0#Y}£,', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/c3b966347e4f6a32c3a9277b_65169.png', 'label': np.str_("ùf4~Oj2é'{"), 'output': "ùf4~oj 2 é '{", 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS55F/2821383b3459723b5550_91684.png', 'label': np.str_('(!8;4Yr;UP'), 'output': '( ! 8 ;4Yr ; U P', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS55F/c3b24744713b79e282ac50795d_33272.png', 'label': np.str_('òGDq;y€Py]'), 'output': 'òG Dq ;yéPy]', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/7926733e782654463663_11489.png', 'label': np.str_('y&s>x&TF6c'), 'output': 'y&s>x &TF6c', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/466bc3b94529615149546e_68512.png', 'label': np.str_('FkùE)aQITn'), 'output': "FKù E) aQ' Tn", 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS55F/c3b27b3a4c71c3ac4f566979_96179.png', 'label': np.str_('ò{:LqìOViy'), 'output': 'ò { : Lq ì oV j y', 'edit_distance': 9}
# {'path': '../dataset/words_dataset/PTS55F/4170573067286e4a6d3b_60892.png', 'label': np.str_('ApW0g(nJm;'), 'output': 'ApW0g (nJ m ;', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/4b6a5667434a2e736c4b_23053.png', 'label': np.str_('KjVgCJ.slK'), 'output': 'KJ Vg CJ . s l K', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS55F/236f6466677b34c3a93852_61900.png', 'label': np.str_('#odfg{4é8R'), 'output': '# o d fg {4é 8 R', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS55F/5a26717d743b335d2c70_63095.png', 'label': np.str_('Z&q}t;3],p'), 'output': 'Z &q}t;S],P', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/764c4d7a543424366145_22505.png', 'label': np.str_('vLMzT4$6aE'), 'output': 'vLM zT4$ 6a E', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/7238673e7b673b405526_66743.png', 'label': np.str_('r8g>{g;@U&'), 'output': 'r8g>{g ;@ U &', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/5d7e734e4164473c616d_40919.png', 'label': np.str_(']~sNAdG<am'), 'output': ']~S NAdG<a m', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/7b75656f56797b37466b_90288.png', 'label': np.str_('{ueoVy{7Fk'), 'output': '{u eoVy{7 F k', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/53476a5a30477b524cc3b9_80662.png', 'label': np.str_('SGjZ0G{RLù'), 'output': 'SGJZ0G{R Lù', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/6a5b4f3252636d797931_13829.png', 'label': np.str_('j[O2Rcmyy1'), 'output': 'j [o2 Rcmyy1', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/5c44684d284ec3b95d3945_90773.png', 'label': np.str_('\\DhM(Nù]9E'), 'output': '\\Dh M (N ù]9 E', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS55F/4732234c354244707b75_60383.png', 'label': np.str_('G2#L5BDp{u'), 'output': 'G2# L5 BDp{u', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/c2a37b58536c2d7872c3b264_69494.png', 'label': np.str_('£{XSl-xròd'), 'output': '£{XS l-X rò d', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS55F/7ac3a87524333849c3b2c2a327_32521.png', 'label': np.str_("zèu$38Iò£'"), 'output': "zèu$ S8 'ò£'", 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS55F/557e2f516b32c3a84d7474_50709.png', 'label': np.str_('U~/Qk2èMtt'), 'output': 'U ~,Qk2 è M tt', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS55F/7d694142667ac3a8e282ac5237_14499.png', 'label': np.str_('}iABfzè€R7'), 'output': '} j A B fzèé R 7', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS55F/6f65497e66c3b94d42c3b96d_39564.png', 'label': np.str_('oeI~fùMBùm'), 'output': "oe' ~fùM Bùm", 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/23336e6f6f72e282ac682f25_67685.png', 'label': np.str_('#3noor€h/%'), 'output': '# S n oo réh,%', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS55F/537263366a2b7b6d3966_10295.png', 'label': np.str_('Src6j+{m9f'), 'output': 'S rc 6J +{m9f', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS55F/6cc2a36c23594c6f726b4f_67577.png', 'label': np.str_('l£l#YLorkO'), 'output': 'l£ l#Y Lo rKO', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS55F/485d5232467a265a3e39_27265.png', 'label': np.str_('H]R2Fz&Z>9'), 'output': 'H] R2 Fz &Z>9', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/665c304f754a3e672f53_63363.png', 'label': np.str_('f\\0OuJ>g/S'), 'output': 'W0O uJ >g,S', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS55F/3fc3ac5c55373428447125_27685.png', 'label': np.str_('?ì\\U74(Dq%'), 'output': '?ì\\U 74(Dq %', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/e282ac5b727e2331596d387a_20685.png', 'label': np.str_('€[r~#1Ym8z'), 'output': 'é [ r~# 1 Ym 8 z', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS55F/794cc2b040247a5b2b6125_36800.png', 'label': np.str_('yL°@$z[+a%'), 'output': 'yL°@ $z[+a%', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/2de282ac4e61485331462434_55056.png', 'label': np.str_('-€NaHS1F$4'), 'output': '-éNaHS1 F$4', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/72612d517570645858c3b9_37802.png', 'label': np.str_('ra-QupdXXù'), 'output': 'ra- Qu pdXX ù', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/623b6d77376b797d2fc3ac_38174.png', 'label': np.str_('b;mw7ky}/ì'), 'output': 'b ;mw7 Ky}a', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS55F/465152265bc3a9e282ac333b26_71231.png', 'label': np.str_('FQR&[é€3;&'), 'output': 'FQR& [ééS ;&', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS55F/54736f2cc3b9314f4b514b_36063.png', 'label': np.str_('Tso,ù1OKQK'), 'output': 'Ts o , ù 1 O KQK', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS55F/2b2b352c2845626a2f73_47098.png', 'label': np.str_('++5,(Ebj/s'), 'output': '++ 5 , (E bj,S', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS55F/c2b0756e594b33c3a9246224_75326.png', 'label': np.str_('°unYK3é$b$'), 'output': '°u nYK Sé$ b$', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS55F/454d422924776e2c764a_46404.png', 'label': np.str_('EMB)$wn,vJ'), 'output': 'E M B) $wn ,vJ', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS55F/7be282ace282ac5245276b4f36c3a9_30534.png', 'label': np.str_("{€€RE'kO6é"), 'output': "{ééR E 'ko6é", 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS55F/27635a476363755a4854_75152.png', 'label': np.str_("'cZGccuZHT"), 'output': "'c ZG cc u Z H T", 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS55F/5544504dc2a3444a294221_67784.png', 'label': np.str_('UDPM£DJ)B!'), 'output': 'U D P M £ DJ) B !', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS55F/23465644496538c3a84e38_44024.png', 'label': np.str_('#FVDIe8èN8'), 'output': "# FVD ' e 8 è N 8", 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS55F/546b39796f6c5772367b_25651.png', 'label': np.str_('Tk9yolWr6{'), 'output': 'TK9yo lWr6{', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/5a54413e57794f2b3470_71283.png', 'label': np.str_('ZTA>WyO+4p'), 'output': 'Z TA > Wy O + 4 p', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS55F/55352130495548533158_58481.png', 'label': np.str_('U5!0IUHS1X'), 'output': "U5 !0' UHS1X", 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/704a443027293a737624_87205.png', 'label': np.str_("pJD0'):sv$"), 'output': "pJ D0 ') :sv$", 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/33794e6ac3b9233a483e59_95449.png', 'label': np.str_('3yNjù#:H>Y'), 'output': 'SyNJ ù#:H>Y', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/c3a9714b5c486945214e6c_66278.png', 'label': np.str_('éqK\\HiE!Nl'), 'output': 'éq K\\H j E ! N l', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS55F/567d593245633e54585c_59870.png', 'label': np.str_('V}Y2Ec>TX\\'), 'output': 'V}Y2 Ec>TX\\', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/24565031c3a97dc3ac6d473e_36817.png', 'label': np.str_('$VP1é}ìmG>'), 'output': '$VP1 é}ì mG>', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/7b4f725527717de282ac7a32_31957.png', 'label': np.str_("{OrU'q}€z2"), 'output': "{o r U 'q }éz 2", 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS55F/6d5975543a3c24305975_38246.png', 'label': np.str_('mYuT:<$0Yu'), 'output': 'mYu T :< $ 0Yu', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS55F/33c3ac46c3b268247d30e282ac64_48060.png', 'label': np.str_('3ìFòh$}0€d'), 'output': 'Sì Fòh$}0éd', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/64796f6dc2b04f5d795ce282ac_25266.png', 'label': np.str_('dyom°O]y\\€'), 'output': 'dyo m °O]y\\é', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/456e3a27273e564f2e3f_21537.png', 'label': np.str_("En:''>VO.?"), 'output': "E n : ' '>VO.?", 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS55F/6961686b7a38473b5269_25763.png', 'label': np.str_('iahkz8G;Ri'), 'output': 'Ja h Kz8G ;RJ', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS55F/507e7d30c3a9555c682b69_99176.png', 'label': np.str_('P~}0éU\\h+i'), 'output': 'P~}0é U\\h + j', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS55F/7e2c6c61c3a8376c5c6627_95980.png', 'label': np.str_("~,laè7l\\f'"), 'output': "~, la è 7 l\\f'", 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS55F/353ac3ac77453e386a2734_60839.png', 'label': np.str_("5:ìwE>8j'4"), 'output': "5 :ìwE>8J '4", 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/3ac3ac397042617a512843_91983.png', 'label': np.str_(':ì9pBazQ(C'), 'output': ':ì 9 P B a zQ(c', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS55F/5c616b264e235b2e404c_53477.png', 'label': np.str_('\\ak&N#[.@L'), 'output': '\\a k & N # [. @ L', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS55F/c2b0295850752630725c46_63950.png', 'label': np.str_('°)XPu&0r\\F'), 'output': '°)X Pu & 0r\\F', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/c2a36f6c67722c3c3ac3a832_92975.png', 'label': np.str_('£olgr,<:è2'), 'output': '£o lg r,< :è 2', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS55F/61364e3b3c514654612c_41343.png', 'label': np.str_('a6N;<QFTa,'), 'output': 'a 6 N ;<QFTa ,', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS55F/406328c2b02465233a57c3a8_43579.png', 'label': np.str_('@c(°$e#:Wè'), 'output': '@ c (° $ e# :Wè', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS55F/426965282f6421334976_94127.png', 'label': np.str_('Bie(/d!3Iv'), 'output': "B J e (,d ! S ' v", 'edit_distance': 11}
# {'path': '../dataset/words_dataset/PTS55F/34412061237854784e48_87979.png', 'label': np.str_('4A a#xTxNH'), 'output': '4A a#xTxN H', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/7d3a4767354d51385570_28080.png', 'label': np.str_('}:Gg5MQ8Up'), 'output': '}:Gg5 MQ8 UP', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/7a33c3b25b717a45756dc3b9_36817.png', 'label': np.str_('z3ò[qzEumù'), 'output': 'zSò [qzEumù', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/203f6e776378745ce282ac40_51486.png', 'label': np.str_(' ?nwcxt\\€@'), 'output': '? n WcXt\\é @', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS55F/56403e3139c3b94e635a39_42797.png', 'label': np.str_('V@>19ùNcZ9'), 'output': 'V@>19ù NcZ9', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/4c543659646534353074_51682.png', 'label': np.str_('LT6Yde450t'), 'output': 'LT 6 Y d e 4 5 0 t', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS55F/794e5067c2b04f752c4035_96214.png', 'label': np.str_('yNPg°Ou,@5'), 'output': 'yN Pg °Ou,@ 5', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/783f2b787848c2a3676d53_97623.png', 'label': np.str_('x?+xxH£gmS'), 'output': 'X?+XXH £g mS', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS55F/e282ac614f7e324b4f656a50_65346.png', 'label': np.str_('€aO~2KOejP'), 'output': 'éao~2 Koej P', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS55F/c2b0273c21342345472b4c_23406.png', 'label': np.str_("°'<!4#EG+L"), 'output': "° '< ! 4# E G+ L", 'edit_distance': 6}
# {'path': '../dataset/words_dataset/Courier Prime/2c2dc2a3494f6130322f45_88210.png', 'label': np.str_(',-£IOa02/E'), 'output': ', -£xOB02,B', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Courier Prime/716e2952c3b27bc3a93f7845_12225.png', 'label': np.str_('qn)Rò{é?xE'), 'output': 'Rn ) Rò{ é ?8B', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/Courier Prime/c3b92940586b457472c3b223_53453.png', 'label': np.str_('ù)@XkEtrò#'), 'output': 'ù ) @XkBtzò#', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Courier Prime/5d324a4d43334e36627a_46409.png', 'label': np.str_(']2JMC3N6bz'), 'output': '] 21Me3N6bz', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Courier Prime/2f516f50274f533621c2b0_86146.png', 'label': np.str_("/QoP'OS6!°"), 'output': ",QoP ' Os6 1 °", 'edit_distance': 7}
# {'path': '../dataset/words_dataset/Courier Prime/3f564fc3a8582b5c382c51_80619.png', 'label': np.str_('?VOèX+\\8,Q'), 'output': '?VOèX+\\ 8 , Q', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Courier Prime/21442b3624c2a35c245731_72817.png', 'label': np.str_('!D+6$£\\$W1'), 'output': '1 O+6$£\\$W1', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Courier Prime/36395d7259703c502d24_12118.png', 'label': np.str_('69]rYp<P-$'), 'output': '6 9 ] zYp<P-$', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Courier Prime/c2a3c3b230355c492c54c3a826_29815.png', 'label': np.str_('£ò05\\I,Tè&'), 'output': '£ò05\\x , ]è&', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Courier Prime/4168515b426550432650_68670.png', 'label': np.str_('AhQ[BePC&P'), 'output': 'AhQ [ BePe&P', 'edit_distance': 3}
# ...
# {'path': '../dataset/words_dataset/Sansation-Bold/656a2434732dc3b9484a38_65169.png', 'label': np.str_('ej$4s-ùHJ8'), 'output': 'eJ$4s-ù HJ8', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/546a7e5a52c3b979c3b94a32_31522.png', 'label': np.str_('Tj~ZRùyùJ2'), 'output': 'TJ ~Z Rùyù J 2', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Sansation-Bold/43702961472f2d425653_60458.png', 'label': np.str_('Cp)aG/-BVS'), 'output': 'c p)a G,- Bvs', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/Sansation-Bold/5562553c4a203f3a3724_11321.png', 'label': np.str_('UbU<J ?:7$'), 'output': 'UbU<J P:7$', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/643c4c6bc3b233727ec3a8c3ac_22764.png', 'label': np.str_('d<Lkò3r~èì'), 'output': 'd < L>ò 3r~èì', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/c3b251733b6a6d787a40c2b0_91336.png', 'label': np.str_('òQs;jmxz@°'), 'output': 'òQs ;j mxz@°', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/5c4e7b7053c3a827e282acc2b050_55999.png', 'label': np.str_("\\N{pSè'€°P"), 'output': "\\N {psè'6 ° P", 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Sansation-Bold/2dc3b24f46415826246736_52499.png', 'label': np.str_('-òOFAX&$g6'), 'output': '-ò o FAxB$g 6', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/Sansation-Bold/573f4d4e365778c3b96631_83175.png', 'label': np.str_('W?MN6Wxùf1'), 'output': 'WP M N 6Wxù f1', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Sansation-Bold/7234c3ac432d31436d7423_32382.png', 'label': np.str_('r4ìC-1Cmt#'), 'output': 'r4ì C - 1 C m Z#', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/Sansation-Bold/2b582b3163c3a9246230c2a3_65964.png', 'label': np.str_('+X+1cé$b0£'), 'output': '.x. 1 cé$ b o£', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/Sansation-Bold/7e4c574c4a25414d2823_17552.png', 'label': np.str_('~LWLJ%AM(#'), 'output': '~LwLJ %AM (#', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/33582c69665cc3a969705a_82120.png', 'label': np.str_('3X,if\\éipZ'), 'output': '3X,i néi pZ', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/725572c3a9684f4c6c294f_36698.png', 'label': np.str_('rUréhOLl)O'), 'output': 'rU réhO Ll) O', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/36487267625a646ec2b02d_70691.png', 'label': np.str_('6HrgbZdn°-'), 'output': '6H rg bZd n °-', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/3976446f314b3c502154_69189.png', 'label': np.str_('9vDo1K<P!T'), 'output': '9vDo1 lK<P!T', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/e282ac264361643a59676f3e_13716.png', 'label': np.str_('€&Cad:Ygo>'), 'output': '6 B C a d : Yg o >', 'edit_distance': 10}
# {'path': '../dataset/words_dataset/Sansation-Bold/267e27584e26e282ac6f48c3ac_73539.png', 'label': np.str_("&~'XN&€oHì"), 'output': "B~'XNB6o Hì", 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/4b6c7e68c3a9c2b0445b547d_85837.png', 'label': np.str_('Kl~hé°D[T}'), 'output': 'lKl ~hé° D[T}', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/7a422e513b364a2b714e_52966.png', 'label': np.str_('zB.Q;6J+qN'), 'output': 'zB.Q;6J.q N', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/3b5d7d4b24c3a85a307223_30582.png', 'label': np.str_(';]}K$èZ0r#'), 'output': ';] } lK$èz or#', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/Sansation-Bold/6264542b65364d2c6c2b_20383.png', 'label': np.str_('bdT+e6M,l+'), 'output': 'bdT.e6 M,l .', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/405c24613559275be282ac69_21260.png', 'label': np.str_("@\\$a5Y'[€i"), 'output': "@\\$a 5Y'[6 i", 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/6476c2a3714a28723c7168_98758.png', 'label': np.str_('dv£qJ(r<qh'), 'output': 'dv£qJ (r<q h', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/394c6d6369284c73736b_49429.png', 'label': np.str_('9Lmci(Lssk'), 'output': '9Lmci ( Lss>', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/32553a4d2b6ec2b072c2b07a_81046.png', 'label': np.str_('2U:M+n°r°z'), 'output': '2U: M.n°r°z', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/6c5d777065c3ac553a2627_32840.png', 'label': np.str_("l]wpeìU:&'"), 'output': "l]wpeì U: B'", 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/c3a94d6c30c2a379784c6765_44711.png', 'label': np.str_('éMl0£yxLge'), 'output': 'é M l o£.Lg e', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/Sansation-Bold/71477b23632727765a5d_68506.png', 'label': np.str_("qG{#c''vZ]"), 'output': "q G{#c' 'vZ]", 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/357b72776c55564e5230_29843.png', 'label': np.str_('5{rwlUVNR0'), 'output': '5{rwl UVN RO', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/77544b44763e3a3129c3a8_27492.png', 'label': np.str_('wTKDv>:1)è'), 'output': 'wTlKDv> : 1 ) è', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Sansation-Bold/203474332b262b3c616a_23625.png', 'label': np.str_(' 4t3+&+<aj'), 'output': '4z3. B. <aJ', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/Sansation-Bold/7863486f61615bc2b0646a_82286.png', 'label': np.str_('xcHoaa[°dj'), 'output': 'xc H oa a [°dJ', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Sansation-Bold/396237675dc3ac6838416d_27306.png', 'label': np.str_('9b7g]ìh8Am'), 'output': '9b7g]ì h8Am', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/2d40685442313e29c3acc3a8_28821.png', 'label': np.str_('-@hTB1>)ìè'), 'output': '-@hTB1 >)ìè', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/73636c683061c2b0732c43_24768.png', 'label': np.str_('sclh0a°s,C'), 'output': 'scl hOa °s,C', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/3bc2b0355b7a695a2c4b4c_58933.png', 'label': np.str_(';°5[ziZ,KL'), 'output': ';° 5[zi z,lKL', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/c3ac3c6b5754586fc2b05361_17079.png', 'label': np.str_('ì<kWTXo°Sa'), 'output': 'ì < >wTxo °sa', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/Sansation-Bold/2c6a4d463451694e5563_67754.png', 'label': np.str_(',jMF4QiNUc'), 'output': ',j M F4Q i N Uc', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Sansation-Bold/2e326b58617d52704332_24709.png', 'label': np.str_('.2kXa}RpC2'), 'output': '.2>xa }Rpc2', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/636d4ac2b027712b71254d_47204.png', 'label': np.str_("cmJ°'q+q%M"), 'output': "cmJ °'q .q % M", 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Sansation-Bold/6ce282ac2578c3a94223545647_29062.png', 'label': np.str_('l€%xéB#TVG'), 'output': 'l 6 %xé B #WG', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/Sansation-Bold/652f312e305541406129_14903.png', 'label': np.str_('e/1.0UA@a)'), 'output': 'e,1 .OUA@a )', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/744dc2a375e282ac6531482d2c_76387.png', 'label': np.str_('tM£u€e1H-,'), 'output': 'zM£u6e1 H-,', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/50797161c3a82928595320_34067.png', 'label': np.str_('Pyqaè)(YS '), 'output': 'Wq a è) (YS', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/Sansation-Bold/c3b26841443c5c4be282ac3e3b_26707.png', 'label': np.str_('òhAD<\\K€>;'), 'output': 'òhAD<\\lK6 > ;', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/667e3be282ac2f3435e282ac7954_36172.png', 'label': np.str_('f~;€/45€yT'), 'output': 'f~ ; 6 ,4 5 6 yT', 'edit_distance': 9}
# {'path': '../dataset/words_dataset/Sansation-Bold/41545b7a3330482c397b_30653.png', 'label': np.str_('AT[z30H,9{'), 'output': 'AT [ z 3 O H , 9 {', 'edit_distance': 9}
# {'path': '../dataset/words_dataset/Sansation-Bold/2f41463c213c24686e7b_22035.png', 'label': np.str_('/AF<!<$hn{'), 'output': ',AF< ! <$h n{', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/384538746546c3a97e2769_12777.png', 'label': np.str_("8E8teFé~'i"), 'output': "8E8ze Fé~'i", 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/77455dc3b93f55422b5730_43931.png', 'label': np.str_('wE]ù?UB+W0'), 'output': 'wE]ù PU B.WO', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Sansation-Bold/23555b325a5849535c50_12541.png', 'label': np.str_('#U[2ZXIS\\P'), 'output': '# U [2zxls\\P', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/Sansation-Bold/62664dc2a33e29503f512e_20408.png', 'label': np.str_('bfM£>)P?Q.'), 'output': 'bfM £ >) PPQ .', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Sansation-Bold/70786c4479c3b971402846_64580.png', 'label': np.str_('pxlDyùq@(F'), 'output': 'pxl Dyù q @(F', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/3079364c626535584dc3a9_70629.png', 'label': np.str_('0y6Lbe5XMé'), 'output': 'Oy6 L be 5XM é', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Sansation-Bold/777e7d3b35304a77c3ac35_20270.png', 'label': np.str_('w~};50Jwì5'), 'output': 'W~ } ; 5oJ Wì 5', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/Sansation-Bold/394e292643213e322464_41151.png', 'label': np.str_('9N)&C!>2$d'), 'output': '9 N) BC ! > 2$d', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/Sansation-Bold/6a703275532bc2b07b4778_33239.png', 'label': np.str_('jp2uS+°{Gx'), 'output': 'J p2uS.°{Gx', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/75527e47377942325b58_66092.png', 'label': np.str_('uR~G7yB2[X'), 'output': 'u R~G7yB2[X', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/362576412874c3b95c4ec3a8_48810.png', 'label': np.str_('6%vA(tù\\Nè'), 'output': '6%vA( zù \\ N è', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Sansation-Bold/5072267dc3b26f7451257b_87880.png', 'label': np.str_('Pr&}òotQ%{'), 'output': 'PrB}òozQ %{', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/6c463f28464e3a5c3623_65047.png', 'label': np.str_('lF?(FN:\\6#'), 'output': 'l FP(FN:\\6#', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/3f3444402e413e556258_69005.png', 'label': np.str_('?4D@.A>UbX'), 'output': 'P4D@.A> UbX', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/36c2a355447878364d7b5c_13599.png', 'label': np.str_('6£UDxx6M{\\'), 'output': '6£ U Dw6M {\\', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Sansation-Bold/63343b6552506f7657c2b0_83541.png', 'label': np.str_('c4;eRPovW°'), 'output': 'c4;e RPovW°', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/3b6a6c522127637b7046_31248.png', 'label': np.str_(";jlR!'c{pF"), 'output': ";j l R! 'c{p F", 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/7a7a573a687064504d7e_52510.png', 'label': np.str_('zzW:hpdPM~'), 'output': 'zzw: hpd PM ~', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/c3b2357775774e4232797b_84011.png', 'label': np.str_('ò5wuwNB2y{'), 'output': 'ò 5WuWN B2y{', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/6c6270694179c3b2556d5d_13187.png', 'label': np.str_('lbpiAyòUm]'), 'output': 'l b p i Ayò U m ]', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/Sansation-Bold/2ec3b93544c3a83f2d6f2d35_13420.png', 'label': np.str_('.ù5Dè?-o-5'), 'output': '.ù 5 DèP-o- 5', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/6d7e4b404a41527e2951_47189.png', 'label': np.str_('m~K@JAR~)Q'), 'output': 'm ~lK@JAR~) Q', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/5c20c3ac54615a7427c2b074_77969.png', 'label': np.str_("\\ ìTaZt'°t"), 'output': "\\ ìTa zz' °z", 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Sansation-Bold/4fc3b9c3a8684b2f2625364c_60353.png', 'label': np.str_('OùèhK/&%6L'), 'output': 'o ùèh lK,B%6L', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/Sansation-Bold/27494026496d2c6d3641_64672.png', 'label': np.str_("'I@&Im,m6A"), 'output': "' l @Bl m,m 6A", 'edit_distance': 7}
# {'path': '../dataset/words_dataset/Sansation-Bold/68395727564761426f78_30739.png', 'label': np.str_("h9W'VGaBox"), 'output': "h 9W'VGa Box", 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/c3ac494c407b2453724e72_99004.png', 'label': np.str_('ìIL@{$SrNr'), 'output': 'ì l L@{$srNr', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/483e62336d3825707868_15182.png', 'label': np.str_('H>b3m8%pxh'), 'output': 'H> b3m 8%pxh', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/7d424a3a4e6249483829_54886.png', 'label': np.str_('}BJ:NbIH8)'), 'output': '}BJ : N b l H 8)', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/Sansation-Bold/3171314d734b6b20c3a947_98459.png', 'label': np.str_('1q1MsKk éG'), 'output': '1q1MslK> éG', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/3a407a21645821536632_51210.png', 'label': np.str_(':@z!dX!Sf2'), 'output': ': @z ! d x! s f2', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/Sansation-Bold/5b3174702b73204c37c3a9_57921.png', 'label': np.str_('[1tp+s L7é'), 'output': '[1zp.s L7é', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/36496852524e6f446b42_54911.png', 'label': np.str_('6IhRRNoDkB'), 'output': '6l h RRNo D> B', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/Sansation-Bold/2526494553c3ac5b2bc3b240_57155.png', 'label': np.str_('%&IESì[+ò@'), 'output': '%Bl Esì [.ò@', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/Sansation-Bold/75454b6b4363242c3052_70722.png', 'label': np.str_('uEKkCc$,0R'), 'output': 'u E lK>Cc$,O R', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/Sansation-Bold/3f4053c3ac764821553942_11569.png', 'label': np.str_('?@SìvH!U9B'), 'output': 'P@sìvH ! U 9 B', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/Sansation-Bold/4f51384e4dc3b229333a6f_40540.png', 'label': np.str_('OQ8NMò)3:o'), 'output': 'OQ8N Mò)3:o', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/425c596a676745257d52_46101.png', 'label': np.str_('B\\YjggE%}R'), 'output': 'B\\YJ g g E %} R', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/Sansation-Bold/5456517a523855505224_34135.png', 'label': np.str_('TVQzR8UPR$'), 'output': 'WQ z R8 U P R$', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/Sansation-Bold/576a3848595b7a57683b_84473.png', 'label': np.str_('Wj8HY[zWh;'), 'output': 'WJ 8 H Y[ zWh ;', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/Sansation-Bold/694146c3b253307b334965_79232.png', 'label': np.str_('iAFòS0{3Ie'), 'output': 'iAFòSO{3 le', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/4d466f746a4156534749_17422.png', 'label': np.str_('MFotjAVSGI'), 'output': 'M F o zJ AV S G l', 'edit_distance': 10}
# {'path': '../dataset/words_dataset/Sansation-Bold/403e46486e556f6661c3ac_12338.png', 'label': np.str_('@>FHnUofaì'), 'output': '@> F H n U o #aì', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/Sansation-Bold/372662736351444dc3a842_73018.png', 'label': np.str_('7&bscQDMèB'), 'output': '7BbscQ DM è B', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/593965704c5d3ec3ac4e3f_87093.png', 'label': np.str_('Y9epL]>ìN?'), 'output': 'Y9ep L]>ì N P', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/454c706123634c7a2155_53840.png', 'label': np.str_('ELpa#cLz!U'), 'output': 'ELpa#cLz! U', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/4971496758643942c2a37e_46212.png', 'label': np.str_('IqIgXd9B£~'), 'output': 'lq lgXd 9 B£ ~', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/Sansation-Bold/442e514d77245a4e7663_97250.png', 'label': np.str_('D.QMw$ZNvc'), 'output': 'D.Q Mw$ZNvc', 'edit_distance': 1}
