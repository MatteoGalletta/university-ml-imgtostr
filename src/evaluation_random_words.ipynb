# %%
# !pip install torchvision matplotlib numpy tensorboard standard-imghdr torchnet scikit-learn opencv-python Levenshtein
# Out:
# Requirement already satisfied: torchvision in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (0.22.0+xpu)
# Requirement already satisfied: matplotlib in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (3.10.3)
# Requirement already satisfied: numpy in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (2.1.2)
# Requirement already satisfied: tensorboard in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (2.19.0)
# Requirement already satisfied: standard-imghdr in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (3.13.0)
# Requirement already satisfied: torchnet in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (0.0.4)
# Requirement already satisfied: scikit-learn in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (1.6.1)
# Requirement already satisfied: opencv-python in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (4.11.0.86)
# Requirement already satisfied: Levenshtein in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (0.27.1)
# Requirement already satisfied: torch==2.7.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torchvision) (2.7.0+xpu)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: filelock in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (4.12.2)
# Requirement already satisfied: setuptools in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (1.13.3)
# Requirement already satisfied: networkx in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (3.3)
# Requirement already satisfied: jinja2 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (2024.6.1)
# Requirement already satisfied: intel-cmplr-lib-rt==2025.0.4 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (2025.0.4)
# Requirement already satisfied: intel-cmplr-lib-ur==2025.0.4 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (2025.0.4)
# Requirement already satisfied: intel-cmplr-lic-rt==2025.0.4 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (2025.0.4)
# Requirement already satisfied: intel-sycl-rt==2025.0.4 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (2025.0.4)
# Requirement already satisfied: tcmlib==1.2.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (1.2.0)
# Requirement already satisfied: umf==0.9.1 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (0.9.1)
# Requirement already satisfied: intel-pti==0.10.1 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (0.10.1)
# Requirement already satisfied: pytorch-triton-xpu==3.3.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torch==2.7.0->torchvision) (3.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: absl-py>=0.4 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from tensorboard) (2.2.2)
# Requirement already satisfied: grpcio>=1.48.2 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from tensorboard) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from tensorboard) (3.8)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from tensorboard) (6.31.0)
# Requirement already satisfied: six>1.9 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from tensorboard) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: visdom in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from torchnet) (0.2.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from Levenshtein) (3.13.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Requirement already satisfied: requests in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from visdom->torchnet) (2.32.3)
# Requirement already satisfied: tornado in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from visdom->torchnet) (6.5)
# Requirement already satisfied: jsonpatch in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from visdom->torchnet) (1.33)
# Requirement already satisfied: websocket-client in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from visdom->torchnet) (1.8.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from sympy>=1.13.3->torch==2.7.0->torchvision) (1.3.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from jsonpatch->visdom->torchnet) (3.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from requests->visdom->torchnet) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from requests->visdom->torchnet) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from requests->visdom->torchnet) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/teogalletta/Documents/university-ml-imgtostr/.venv/lib64/python3.13/site-packages (from requests->visdom->torchnet) (2025.4.26)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# imports
import matplotlib.pyplot as plt
import numpy as np

import torch
import torchvision
import torchvision.transforms as transforms

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torch.utils.data.dataset import Dataset
from PIL import Image, ImageDraw, ImageFont
from sklearn.metrics import accuracy_score

from torch.utils.tensorboard import SummaryWriter

from ImageToStringNet import ImageToStringNet, classes
from ImageToStringNetDropout import ImageToStringNetDropout

import Levenshtein
import sys
sys.path.append('../core')
from main import process_image

# %% [markdown]
# # Evaluation

# %%
words_dir = "../dataset/words_dataset"
words_dataset = np.loadtxt(f'{words_dir}/dataset.txt', dtype=str, delimiter='\t', comments=[])

# %%
len(words_dataset)
# Out:
# 1500

# %%
results = []
for i, data in enumerate(words_dataset):
	img_path = f'{words_dir}/{data[0]}'
	print("Processing: ", img_path)
	print(data[1])
	img = Image.open(img_path)
	try:
		_, output = process_image(img)
		edit_distance = Levenshtein.distance(data[1], output)

		results.append({
			'path': img_path,
			'label': data[1],
			'output': output,
			'edit_distance': edit_distance
		})
		print(f'{output}\nEDIT DISTANCE: {edit_distance}\n')
	except Exception as e:
		print(f'Error: {e}')
		results.append({
			'path': img_path,
			'label': data[1],
			'output': None,
			'edit_distance': None,
			'error': e
		})
# Out:
# Processing:  ../dataset/words_dataset/Lato-Medium/2e50447b593857e282acc3a924_32221.png
# .PD{Y8W€é$
# .PD{Y8W€é$
# EDIT DISTANCE: 0
#
# Processing:  ../dataset/words_dataset/Lato-Medium
# EDIT DISTANCE: 0
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/c3ac494c407b2453724e72_99004.png
# ìIL@{$SrNr
# ìlL4{$srNr
# EDIT DISTANCE: 3
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/483e62336d3825707868_15182.png
# H>b3m8%pxh
# H>b3m8%pxh
# EDIT DISTANCE: 0
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/7d424a3a4e6249483829_54886.png
# }BJ:NbIH8)
# }BJ:NblH8)
# EDIT DISTANCE: 1
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/3171314d734b6b20c3a947_98459.png
# 1q1MsKk éG
# 1q1Msl<béG
# EDIT DISTANCE: 3
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/3a407a21645821536632_51210.png
# :@z!dX!Sf2
# :4z!dx!sr2
# EDIT DISTANCE: 4
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/5b3174702b73204c37c3a9_57921.png
# [1tp+s L7é
# [1tp+sL7é
# EDIT DISTANCE: 1
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/36496852524e6f446b42_54911.png
# 6IhRRNoDkB
# 6lhRRNoDbB
# EDIT DISTANCE: 2
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/2526494553c3ac5b2bc3b240_57155.png
# %&IESì[+ò@
# %blEsì[+ò4
# EDIT DISTANCE: 4
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/75454b6b4363242c3052_70722.png
# uEKkCc$,0R
# uEl<bCc$,OR
# EDIT DISTANCE: 4
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/3f4053c3ac764821553942_11569.png
# ?@SìvH!U9B
# ?4sìvH!U9B
# EDIT DISTANCE: 2
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/4f51384e4dc3b229333a6f_40540.png
# OQ8NMò)3:o
# OQ8NMò)3:o
# EDIT DISTANCE: 0
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/425c596a676745257d52_46101.png
# B\YjggE%}R
# B\YJggE%}R
# EDIT DISTANCE: 1
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/5456517a523855505224_34135.png
# TVQzR8UPR$
# WQzR8UPR$
# EDIT DISTANCE: 2
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/576a3848595b7a57683b_84473.png
# Wj8HY[zWh;
# WJ8HY[zWh;
# EDIT DISTANCE: 1
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/694146c3b253307b334965_79232.png
# iAFòS0{3Ie
# iAFòSO{3le
# EDIT DISTANCE: 2
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/4d466f746a4156534749_17422.png
# MFotjAVSGI
# MFotJAVSGl
# EDIT DISTANCE: 2
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/403e46486e556f6661c3ac_12338.png
# @>FHnUofaì
# 4>FHnUoraì
# EDIT DISTANCE: 2
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/372662736351444dc3a842_73018.png
# 7&bscQDMèB
# 7bbscQDMèB
# EDIT DISTANCE: 1
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/593965704c5d3ec3ac4e3f_87093.png
# Y9epL]>ìN?
# Y9epL]>ìN?
# EDIT DISTANCE: 0
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/454c706123634c7a2155_53840.png
# ELpa#cLz!U
# ELpa#cLz!U
# EDIT DISTANCE: 0
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/4971496758643942c2a37e_46212.png
# IqIgXd9B£~
# lqlgXd9B£~
# EDIT DISTANCE: 2
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/62653a5c3e7e542720c3a9_45434.png
# be:\>~T' é
# be:\>~T'é
# EDIT DISTANCE: 1
#
# Processing:  ../dataset/words_dataset/Sansation-Bold/442e514d77245a4e7663_97250.png
# D.QMw$ZNvc
# D.QMw$ZNvc
# EDIT DISTANCE: 0

# %%
results[0]
edit_distances = [result['edit_distance'] for result in results if result['edit_distance'] is not None]
mean = np.mean(edit_distances)
variance = np.var(edit_distances)
minimum = np.min(edit_distances)
maximum = np.max(edit_distances)

print(f"Mean: {mean}, Variance: {variance}, Min: {minimum}, Max: {maximum}")
# Out:
# Mean: 2.268111035883548, Variance: 20.193519316039342, Min: 0, Max: 36

# %%
max_edit_distance_objects = [result for result in results if result['edit_distance'] == maximum]
print(max_edit_distance_objects)
# Out:
# [{'path': '../dataset/words_dataset/Lato-Hairline/756e7a6d752351525275_73001.png', 'label': np.str_('unzmu#QRRu'), 'output': '<... -N.:.-~4-~.<...<:::~..:: ::<...', 'edit_distance': 36}]

# %%
# Filter and print objects containing errors
error_objects = [result for result in results if 'error' in result]
print("Objects with errors:")
for obj in error_objects:
	print(obj)
# Out:
# Objects with errors:
# {'path': '../dataset/words_dataset/Lato-Light/5b613b2f686b6c545d3e_60919.png', 'label': np.str_('[a;/hklT]>'), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Light/566c77c2a3316e26423832_97465.png', 'label': np.str_('Vlw£1n&B82'), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Light/566c5c732f556250583c_53287.png', 'label': np.str_('Vl\\s/UbPX<'), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Light/28453a766c273e2734c3b9_83263.png', 'label': np.str_("(E:vl'>'4ù"), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Light/646c5d7329686b733473_19744.png', 'label': np.str_('dl]s)hks4s'), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Light/624cc3a925e282ac6e4d6c482c_25668.png', 'label': np.str_('bLé%€nMlH,'), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Light/5d5a723b61402e2d6c3c_12081.png', 'label': np.str_(']Zr;a@.-l<'), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Light/7159256e27264f5c6c27_52878.png', 'label': np.str_("qY%n'&O\\l'"), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Light/373a61686c267b276b6e_15542.png', 'label': np.str_("7:ahl&{'kn"), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Light/2c71795327c2a3c3a96c7e41_87453.png', 'label': np.str_(",qyS'£él~A"), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Light/67686e6c40302b2b2052_29661.png', 'label': np.str_('ghnl@0++ R'), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Light/c2b061613e375b6c3b2557_71871.png', 'label': np.str_('°aa>7[l;%W'), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Light/6e66657152546c262067_35373.png', 'label': np.str_('nfeqRTl& g'), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Light/347226682e6d6c32682f_13142.png', 'label': np.str_('4r&h.ml2h/'), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Light/686c7a61374170492d76_59617.png', 'label': np.str_('hlza7ApI-v'), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Hairline/2b6936447b7033c3b229c3a9_97085.png', 'label': np.str_('+i6D{p3ò)é'), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Hairline/495665367b504e452325_14516.png', 'label': np.str_('IVe6{PNE#%'), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Hairline/2b53c2b03f213b327b402b_73507.png', 'label': np.str_('+S°?!;2{@+'), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Hairline/3a3271737a4279697b66_97087.png', 'label': np.str_(':2qszByi{f'), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Hairline/c3a833406938687b3b4b61_10212.png', 'label': np.str_('è3@i8h{;Ka'), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Hairline/5a4361c2b0516b585b217b_50077.png', 'label': np.str_('ZCa°QkX[!{'), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Hairline/6e7b5a3b3c6e42465b6d_78028.png', 'label': np.str_('n{Z;<nBF[m'), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}
# {'path': '../dataset/words_dataset/Lato-Hairline/336f2b6d44615d7b2f46_58199.png', 'label': np.str_('3o+mDa]{/F'), 'output': None, 'edit_distance': None, 'error': error("OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'\n")}

# %%
len(error_objects)
# Out:
# 23

# %%
correct_predictions_case = sum(1 for result in results if result['output'] and result['label'] == result['output'])
correct_predictions = sum(1 for result in results if result['output'] and result['label'].lower() == result['output'].lower())
correct_predictions_no_spaces = sum(
	1 for result in results 
	if result['output'] and result['label'].replace(" ", "").lower() == result['output'].replace(" ", "").lower()
)
correct_predictions_no_spaces_no_Il = sum(
	1 for result in results
	if result['output'] and result['label'].replace(" ", "").replace("I", "l").lower() == result['output'].replace(" ", "").replace("I", "l").lower()
)

accuracy_case = correct_predictions_case / len(results) * 100
accuracy = correct_predictions / len(results) * 100
accuracy_no_spaces = correct_predictions_no_spaces / len(results) * 100
accuracy_no_spaces_no_Il = correct_predictions_no_spaces_no_Il / len(results) * 100

print(f"Accuracy (case sensitive): {accuracy_case:.2f}%")
print(f"Accuracy (case insensitive): {accuracy:.2f}%")
print(f"Accuracy (case insensitive, no spaces inside): {accuracy_no_spaces:.2f}%")
print(f"Accuracy (case insensitive, no spaces inside, no Il diff): {accuracy_no_spaces_no_Il:.2f}%")
# Out:
# Accuracy (case sensitive): 34.73%
# Accuracy (case insensitive): 50.73%
# Accuracy (case insensitive, no spaces inside): 55.67%
# Accuracy (case insensitive, no spaces inside, no Il diff): 59.20%

# %%
# Stampa i risultati con edit_distance diverso da 0
nonzero_edit_distance = [result for result in results if result['output'] and result['label'] != result['output']]
for r in nonzero_edit_distance:
    print(r)
# Out:
# {'path': '../dataset/words_dataset/Lato-Medium/76774e634770415c666b_81035.png', 'label': np.str_('vwNcGpA\\fk'), 'output': 'vwNcGpA\\)', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/577b32352bc3b9762b4437_74553.png', 'label': np.str_('W{25+ùv+D7'), 'output': 'W{25+ùV+D7', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/4f3b513b704d29213577_91954.png', 'label': np.str_('O;Q;pM)!5w'), 'output': 'o;Q;pM)!5W', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/56705353563b6225c2a350_53779.png', 'label': np.str_('VpSSV;b%£P'), 'output': 'vpssv;b%£P', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Lato-Medium/6b552c51792c6e324449_49559.png', 'label': np.str_('kU,Qy,n2DI'), 'output': 'kU,Qy,n2Dl', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/71696a524d4b212664c2a3_15651.png', 'label': np.str_('qijRMK!&d£'), 'output': 'qiJRMK!&d£', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/254740537220244ec2a379_98203.png', 'label': np.str_('%G@Sr $N£y'), 'output': '%G@sr$N£y', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/7e56613a51497d4c407b_28146.png', 'label': np.str_('~Va:QI}L@{'), 'output': '~va:Ql}L@{', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/77c2b032573f5b6f552b33_81701.png', 'label': np.str_('w°2W?[oU+3'), 'output': 'W°2W?[oU+3', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/4a3fc2b03a53543a4e2d67_84362.png', 'label': np.str_('J?°:ST:N-g'), 'output': 'J?°:sT:N-g', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/4323547a75794fc3b2c2b035_98857.png', 'label': np.str_('C#TzuyOò°5'), 'output': 'c#Tzuyoò°5', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/5d6124754f7146532974_85687.png', 'label': np.str_(']a$uOqFS)t'), 'output': ']a$uoqFs)t', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/4a51c3b96775296b33586d_93586.png', 'label': np.str_('JQùgu)k3Xm'), 'output': 'JQùgu)K3Xm', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/773a7a755167c3a8c3b2387e_33044.png', 'label': np.str_('w:zuQgèò8~'), 'output': 'W:zuQgèò8~', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/7754372534c3b256494358_98772.png', 'label': np.str_('wT7%4òVICX'), 'output': 'wT7%4òVlCX', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/27597b2b3e574c454964_26319.png', 'label': np.str_("'Y{+>WLEId"), 'output': "'Y{+>WLEld", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/4f286d7e5962446cc3b967_84230.png', 'label': np.str_('O(m~YbDlùg'), 'output': 'o(m~YbDlùg', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/6647397d3b2e252f5621_89680.png', 'label': np.str_('fG9};.%/V!'), 'output': 'fG9};.%,V!', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/277753e282acc3ac3a6f3b202e_31570.png', 'label': np.str_("'wS€ì:o; ."), 'output': "'Ws€ì:o;.", 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Lato-Medium/5271252f4143c3a8c2a33257_51859.png', 'label': np.str_('Rq%/ACè£2W'), 'output': 'Rq%,ACè£2W', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/665b445043212028254b_38924.png', 'label': np.str_('f[DPC! (%K'), 'output': 'f[DPC!(%K', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/77622b506e5a332c6b27_56508.png', 'label': np.str_("wb+PnZ3,k'"), 'output': "wb+PnZ3,K'", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/587d3a3e7667c3b2533b6a_86257.png', 'label': np.str_('X}:>vgòS;j'), 'output': 'X}:>Vgòs;j', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/28732b20754a6ec3b93676_90122.png', 'label': np.str_('(s+ uJnù6v'), 'output': '(s+uJnù6V', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/29516e206fc3ac2b566967_29994.png', 'label': np.str_(')Qn oì+Vig'), 'output': ')Qnoì+vig', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/4054c3b96d727443614527_95995.png', 'label': np.str_("@TùmrtCaE'"), 'output': "@TùmrtcaE'", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/5d6e5557352f79535770_35331.png', 'label': np.str_(']nUW5/ySWp'), 'output': ']nUW5,ysWp', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/c3b257c3a82f552e74685179_10304.png', 'label': np.str_('òWè/U.thQy'), 'output': 'òWè,U.thQy', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/6d594747357e3e2b4d6b_15899.png', 'label': np.str_('mYGG5~>+Mk'), 'output': 'mYGG5~>+MK', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/7a26c3ac79392048557967_87903.png', 'label': np.str_('z&ìy9 HUyg'), 'output': 'z&ìy9HUyg', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/4fc2a3455c32616f7a4c2d_79853.png', 'label': np.str_('O£E\\2aozL-'), 'output': 'o£E\\2aozL-', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/2ec3ac496470c3b257763c3e_51118.png', 'label': np.str_('.ìIdpòWv<>'), 'output': '.ìldpòWV<>', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/3c6d5637262741455c3c_64807.png', 'label': np.str_("<mV7&'AE\\<"), 'output': "<mv7&'AE\\<", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/216123743128c3ace282acc3a94f_10347.png', 'label': np.str_('!a#t1(ì€éO'), 'output': '!a#t1(ì€éo', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/6a305577682726c2b0326b_30898.png', 'label': np.str_("j0Uwh'&°2k"), 'output': "J0Uwh'&°2K", 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/6a6c655c7d694e3e316d_61599.png', 'label': np.str_('jle\\}iN>1m'), 'output': 'Jle\\}iN>1m', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/357848626326775a6b4d_57001.png', 'label': np.str_('5xHbc&wZkM'), 'output': '5xHbc&wZKM', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/45743966c3a82f5a5a234d_42343.png', 'label': np.str_('Et9fè/ZZ#M'), 'output': 'Et9fè,ZZ#M', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/c3ac68687a506f4ec3b25a77_12657.png', 'label': np.str_('ìhhzPoNòZw'), 'output': 'ìhhzPoNòzW', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/e282ac465071362f23c3a93f64_16572.png', 'label': np.str_('€FPq6/#é?d'), 'output': '€FPq6,#é?d', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/39614042c3b95427412f3b_86736.png', 'label': np.str_("9a@BùT'A/;"), 'output': "9a@BùT'A,;", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/76303a502c3b413f2f6a_31353.png', 'label': np.str_('v0:P,;A?/j'), 'output': 'v0:P,;A?,J', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/623f43406a4e40c2a34a65_99907.png', 'label': np.str_('b?C@jN@£Je'), 'output': 'b?C@JN@£Je', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/6824356b713c747a3063_95556.png', 'label': np.str_('h$5kq<tz0c'), 'output': 'h$5Kq<tz0c', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/33764b4b46733c774e20_73678.png', 'label': np.str_('3vKKFs<wN '), 'output': '3vKKFs<wN', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/c3ac597170354a275a6e39_35453.png', 'label': np.str_("ìYqp5J'Zn9"), 'output': "ìYqp5J'zn9", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/6849474f3521206ac3ac55_51173.png', 'label': np.str_('hIGO5! jìU'), 'output': 'hlGO5!JìU', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Lato-Medium/5c567a67342658c3b9776a_84274.png', 'label': np.str_('\\Vzg4&Xùwj'), 'output': '\\vzg4&XùWj', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Lato-Medium/35c3a9653bc3b94b6c6d6120_96272.png', 'label': np.str_('5ée;ùKlma '), 'output': '5ée;ùKlma', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/6637207a2854c2a3443e54_86314.png', 'label': np.str_('f7 z(T£D>T'), 'output': 'f7z(T£D>T', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/24527032362044263246_41062.png', 'label': np.str_('$Rp26 D&2F'), 'output': '$Rp26D&2F', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/c2b0e282ac624e4653c3a8792732_84677.png', 'label': np.str_("°€bNFSèy'2"), 'output': "°€bNFsèy'2", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Lato-Medium/c2a343452778453843695b_48348.png', 'label': np.str_("£CE'xE8Ci["), 'output': "£cE'xE8ci[", 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS56F/213132c3ac584b5244c3b237_42945.png', 'label': np.str_('!12ìXKRDò7'), 'output': '?227XKRDò7', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/29494620584a2863782b_58659.png', 'label': np.str_(')IF XJ(cx+'), 'output': '77FX7écx+', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/6e4441746c6b5545c3a97b_21018.png', 'label': np.str_('nDAtlkUEé{'), 'output': 'nD4tZKUEéé', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/5d64235831593f536271_89142.png', 'label': np.str_(']d#X1Y?Sbq'), 'output': '7d#X2X?Sòq', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/48c2b06ac3ac52235a622e31_96798.png', 'label': np.str_('H°jìR#Zb.1'), 'output': 'H,7R#Zò.2', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/657147317b565a685575_35562.png', 'label': np.str_('eqG1{VZhUu'), 'output': 'eqG2mZhUu', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/c3ac3a34762c4370657756_34324.png', 'label': np.str_('ì:4v,CpewV'), 'output': '7..4%Cpew7', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS56F/243e6b4f3f6a4632c2a357_19402.png', 'label': np.str_('$>kO?jF2£W'), 'output': '$>k0òF2£W', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/4040406f3c36344a7164_74321.png', 'label': np.str_('@@@o<64Jqd'), 'output': '@@@0<647qd', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS56F/615bc2b0574d297b7b346a_41116.png', 'label': np.str_('a[°WM){{4j'), 'output': 'nZOWHééW', 'edit_distance': 9}
# {'path': '../dataset/words_dataset/PTS56F/452441213e75507d686d_16782.png', 'label': np.str_('E$A!>uP}hm'), 'output': 'E$4?>uBhm', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/23302e687a634f717178_73932.png', 'label': np.str_('#0.hzcOqqx'), 'output': '#0.hzc0qqX', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS56F/3462777323204a523a3c_16071.png', 'label': np.str_('4bws# JR:<'), 'output': '4òws#7R..<', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/26c2a334453f3637274631_87283.png', 'label': np.str_("&£4E?67'F1"), 'output': '&£4E?67,F2', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS56F/62455dc3a97929355a4de282ac_29748.png', 'label': np.str_('bE]éy)5ZM€'), 'output': 'òE7é%5zM€', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/e282ac2c38c3a92e3238736cc3a9_62090.png', 'label': np.str_('€,8é.28slé'), 'output': '€8é.28sZé', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS56F/313424693c5c63307227_78690.png', 'label': np.str_("14$i<\\c0r'"), 'output': '24$7<\\c0r,', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/206121484f5163776f56_45609.png', 'label': np.str_(' a!HOQcwoV'), 'output': 'n?H0Qcw07', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS56F/4f3e657263525558544d_28245.png', 'label': np.str_('O>ercRUXTM'), 'output': '0>ercRUXZM', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS56F/6732c2a3356c2944427438_19911.png', 'label': np.str_('g2£5l)DBt8'), 'output': 'g2£5Z7D8t8', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/6b34383c444f56783261_12708.png', 'label': np.str_('k48<DOVx2a'), 'output': 'K48<D0Zx2n', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/c3a84e434269c3a978613674_86405.png', 'label': np.str_('èNCBiéxa6t'), 'output': 'éNc87éXn6t', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS56F/7d2c33323121637a7546_68037.png', 'label': np.str_('},321!czuF'), 'output': '7,322?czuF', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/2b352f6e2d4665782b40_97986.png', 'label': np.str_('+5/n-Fex+@'), 'output': '+57n-FeX+@', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS56F/6a4f4d39415c48292c7e_48270.png', 'label': np.str_('jOM9A\\H),~'), 'output': 'J0M9,\\H,,~', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/c3a968613a793151343b36_21187.png', 'label': np.str_('éha:y1Q4;6'), 'output': 'éhn..y2 Q4,.6', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/615d547127716c754f40_46293.png', 'label': np.str_("a]Tq'qluO@"), 'output': 'n,W,qZu0@', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/61745a6d3a246a5745c3a8_89186.png', 'label': np.str_('atZm:$jWEè'), 'output': 'ntZm..#WEé', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/31302d716d315a425c25_90698.png', 'label': np.str_('10-qm1ZB\\%'), 'output': '20-qm2Z8\\%', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/7a4b633f71343c395638_38719.png', 'label': np.str_('zKc?q4<9V8'), 'output': 'zKc?q4<978', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS56F/5c317867293c54687449_40764.png', 'label': np.str_('\\1xg)<ThtI'), 'output': '\\2Xg,<zht7', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/c2b069316dc3ac686f587851_57189.png', 'label': np.str_('°i1mìhoXxQ'), 'output': 'O72m7h0XxQ', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/5b4d503b705c4b7a6e30_49196.png', 'label': np.str_('[MP;p\\Kzn0'), 'output': 'ZMP,.p\\Kzn0', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/435231c3a8c2b07a3566456d_87704.png', 'label': np.str_('CR1è°z5fEm'), 'output': 'CR2éOz5,Em', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/383864557a44c2b067e282ac4d_51432.png', 'label': np.str_('88dUzD°g€M'), 'output': '88dUzDOg€M', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS56F/4f6fc2a33ec3b27537516179_69300.png', 'label': np.str_('Oo£>òu7Qay'), 'output': '00£>òu7Qny', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/337d2564c3b925c3b24f6147_99870.png', 'label': np.str_('3}%dù%òOaG'), 'output': '37%dù%ò0nG', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/69c3a8397e6133305b52c3ac_31705.png', 'label': np.str_('iè9~a30[Rì'), 'output': '7é9~n30ZR7', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/c3a953e282ac3b63307679c3b92f_65800.png', 'label': np.str_('éS€;c0vyù/'), 'output': 'éS€,.c0,yù7', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/2552463bc3b9c3b25b2f7530_33312.png', 'label': np.str_('%RF;ùò[/u0'), 'output': '%RF,.ùò,u0', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/7b6b4f5865c3ac5c6c4d26_20353.png', 'label': np.str_('{kOXeì\\lM&'), 'output': 'ékQXe7\\ZM&', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/c3a9755362505940c3a85a5a_90728.png', 'label': np.str_('éuSbPY@èZZ'), 'output': 'éuSòP,@ézz', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/556b53247a7a4356542d_43421.png', 'label': np.str_('UkS$zzCVT-'), 'output': 'UkS$zzc@', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/c2a3724bc2a359493c433527_23332.png', 'label': np.str_("£rK£YI<C5'"), 'output': '£rK£x7<c5,', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/46c3b94e49393b45c2a34b28_26379.png', 'label': np.str_('FùNI9;E£K('), 'output': 'FùN79,.E£K(', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/4c2b5c36714f66634371_68869.png', 'label': np.str_('L+\\6qOfcCq'), 'output': 'z+\\6q0#ccq', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/305c4b332b236f752e6c_38742.png', 'label': np.str_('0\\K3+#ou.l'), 'output': '0\\K3+#0u.Z', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS56F/c2a33e6b622b494959645b_30161.png', 'label': np.str_('£>kb+IIYd['), 'output': '£>kò+77%dz', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/7e78567d58313e5a4a5d_45261.png', 'label': np.str_('~xV}X1>ZJ]'), 'output': '~XwX2>ò7', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/7834722956206578c3b97e_90121.png', 'label': np.str_('x4r)V exù~'), 'output': 'x4@7exù~', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/28316a43764038293525_53062.png', 'label': np.str_('(1jCv@8)5%'), 'output': '(2jC,@8,5%', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/5329745c694f59c3a95a7a_53743.png', 'label': np.str_('S)t\\iOYéZz'), 'output': '9t\\70%éZz', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/4a2351c3a857c3a9e282ac453168_87946.png', 'label': np.str_('J#QèWé€E1h'), 'output': '7#QéWé€E2h', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/74c2b0326c2b5662542e69_41531.png', 'label': np.str_('t°2l+VbT.i'), 'output': 'to2z+7bz7', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS56F/212b33c3b279682c437338_42715.png', 'label': np.str_('!+3òyh,Cs8'), 'output': '?+3òyh,Cs8', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS56F/c3b25570207a5a52543677_77146.png', 'label': np.str_('òUp zZRT6w'), 'output': 'òUpzzR,6W', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/6f23346454733b41785b_19891.png', 'label': np.str_('o#4dTs;Ax['), 'output': '0#4db,7Xz', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/3578786858c3a874403b5a_75715.png', 'label': np.str_('5xxhXèt@;Z'), 'output': '5xxhXét@,.Z', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/437d5a4c4c637a6134c3ac_39380.png', 'label': np.str_('C}ZLLcza4ì'), 'output': 'QZZZczn47', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS56F/53622e6e6648c2a3c3ac6766_72307.png', 'label': np.str_('Sb.nfH£ìgf'), 'output': 'Sò.n,H£7g,', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/3c622c48447e426c6467_49036.png', 'label': np.str_('<b,HD~Bldg'), 'output': '<ò,HD~8Zdg', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/33394221276a3538452e_78350.png', 'label': np.str_("39B!'j58E."), 'output': '398?758E.', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/5d556dc2a34d614e517345_44719.png', 'label': np.str_(']Um£MaNQsE'), 'output': '7Um£MnNQsE', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS56F/5c69283a4968562e422d_26390.png', 'label': np.str_('\\i(:IhV.B-'), 'output': '\\7(..7hz8-', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/5b794c373053c2b0736a6f_91041.png', 'label': np.str_('[yL70S°sjo'), 'output': 'ZyZ70SOs70', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/56c3b9612b21667a475a7e_59626.png', 'label': np.str_('Vùa+!fzGZ~'), 'output': '7ùn+PGZ~', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/57c2a324343a455be282ac3f20_53642.png', 'label': np.str_('W£$4:E[€? '), 'output': 'W£$4..Ez€?', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/2f757d302b5d5b287a6a_93068.png', 'label': np.str_('/u}0+][(zj'), 'output': '7u,0+744', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/41696e3b6851304c23c3b2_72753.png', 'label': np.str_('Ain;hQ0L#ò'), 'output': '47n,.hQ0Z#ò', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/44382d2f296855663971_58675.png', 'label': np.str_('D8-/)hUf9q'), 'output': 'D8-,hUAq', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/754b646f6c202d553f7b_15293.png', 'label': np.str_('uKdol -U?{'), 'output': 'uKd0Z-U?é', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/692d63543c6b3028537d_84291.png', 'label': np.str_('i-cT<k0(S}'), 'output': '7-c,<K0(>', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/684d313a232748262467_85518.png', 'label': np.str_("hM1:#'H&$g"), 'output': 'hM2..#,H&$g', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/456168613175252c4144_80968.png', 'label': np.str_('Eaha1u%,AD'), 'output': 'Enhn2u%,4D', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/4f3e52442b69462428c3ac_42931.png', 'label': np.str_('O>RD+iF$(ì'), 'output': '0>RD+7F$(7', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/c3b237383963685b4d773e_74847.png', 'label': np.str_('ò789ch[Mw>'), 'output': 'ò789chéM-', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/7d54c3a92cc3acc3a83f663a37_16212.png', 'label': np.str_('}Té,ìè?f:7'), 'output': '7K,7é,.7', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS56F/6d5d706c6370476f4f28_52902.png', 'label': np.str_('m]plcpGoO('), 'output': 'm7pZcpG00(', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/4457396d34c3a82f36764e_99262.png', 'label': np.str_('DW9m4è/6vN'), 'output': 'DW9m4é,6,N', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/41593072665c7625773a_42803.png', 'label': np.str_('AY0rf\\v%w:'), 'output': '4P0,,%w..', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS56F/7b68c2a330265724634336_11161.png', 'label': np.str_('{h£0&W$cC6'), 'output': 'éh£0&W$cc6', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS56F/3a3e57324c247b3f4661_21641.png', 'label': np.str_(':>W2L${?Fa'), 'output': '..>W2z$é?Fn', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/6f3c4f59426331675c54_27747.png', 'label': np.str_('o<OYBc1g\\T'), 'output': '0<0x8C2g\\,', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/617d5d796d2e432440c2a3_66777.png', 'label': np.str_('a}]ym.C$@£'), 'output': 'n,7ym.C$@£', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/684a53426ac2b05a68c3ac3a_13679.png', 'label': np.str_('hJSBj°Zhì:'), 'output': 'h7S87OZh7..', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/4221342965736d4f4b40_85696.png', 'label': np.str_('B!4)esmOK@'), 'output': '8?#esm0K@', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/26654f69c3a85d3b6c4757_79117.png', 'label': np.str_('&eOiè];lGW'), 'output': '&e07é7,.ZGW', 'edit_distance': 7}
# {'path': '../dataset/words_dataset/PTS56F/55c3ac597331c3b24c38686f_43228.png', 'label': np.str_('UìYs1òL8ho'), 'output': 'U7h2òZ8h0', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS56F/486f5441c3a95a36703877_49768.png', 'label': np.str_('HoTAéZ6p8w'), 'output': 'H0méZ6p8w', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/664c7566534f7448c3a9c3a8_23199.png', 'label': np.str_('fLufSOtHéè'), 'output': ',zuxS0tHéé', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/6c56744a53315a53306e_14473.png', 'label': np.str_('lVtJS1ZS0n'), 'output': 'Z7dS2ZS0n', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/382142386376577a4533_60198.png', 'label': np.str_('8!B8cvWzE3'), 'output': '8?88c,WzE3', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS56F/352f2f3935656264612d_99168.png', 'label': np.str_('5//95ebda-'), 'output': '5#95eòdn-', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/6d417a567a4f26362f35_10918.png', 'label': np.str_('mAzVzO&6/5'), 'output': 'm4zZz0&6Z5', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/5b213a5658477849e282ac20_11005.png', 'label': np.str_('[!:VXGxI€ '), 'output': 'z?..7XGX7€', 'edit_distance': 8}
# {'path': '../dataset/words_dataset/PTS56F/2f214024647746626137_83656.png', 'label': np.str_('/!@$dwFba7'), 'output': '4@$dwFòn7', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/7e7d615a507a2171c3ac34_60580.png', 'label': np.str_('~}aZPz!qì4'), 'output': '~,nzPz?q74', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/PTS56F/385b29553b2e75783c33_38702.png', 'label': np.str_('8[)U;.ux<3'), 'output': '8#U,..ux<3', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS56F/7b6a246353507b575965_62472.png', 'label': np.str_('{j$cSP{WYe'), 'output': '#$cSPé-', 'edit_distance': 6}
# {'path': '../dataset/words_dataset/PTS55F/6d443141304e2b2b50c3a9_25410.png', 'label': np.str_('mD1A0N++Pé'), 'output': 'mD1AON++Pé', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/696843265153486b2c39_79436.png', 'label': np.str_('ihC&QSHk,9'), 'output': 'ihC&QSHK,9', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/7843386c67543c6b583a_43030.png', 'label': np.str_('xC8lgT<kX:'), 'output': 'xC8LgT<KX:', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/4c2561656f3268766f6c_54921.png', 'label': np.str_('L%aeo2hvol'), 'output': 'L%aeo2hvoL', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/68c3a9644d67572f707d5d_57346.png', 'label': np.str_('hédMgW/p}]'), 'output': 'hédMgW,p}]', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/214d46713b554d7d3030_11547.png', 'label': np.str_('!MFq;UM}00'), 'output': '!MFq;UM}oo', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/416c7234524453644f34_73165.png', 'label': np.str_('Alr4RDSdO4'), 'output': 'ALr4RDSdO4', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/6a31c2b0c3b25466417d6244_88403.png', 'label': np.str_('j1°òTfA}bD'), 'output': 'J1°òTfA}bD', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/7e714e547d20e282ac32c2a326_40568.png', 'label': np.str_('~qNT} €2£&'), 'output': '~qNT}€2£&', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/2bc3b94c676e3026786253_63714.png', 'label': np.str_('+ùLgn0&xbS'), 'output': '+ùLgno&XbS', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/c3b93e3772652f39235c30_21016.png', 'label': np.str_('ù>7re/9#\\0'), 'output': 'ù>7re,9#\\o', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/63516f6f726820614c66_24054.png', 'label': np.str_('cQoorh aLf'), 'output': 'cQoorhaLf', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/6cc2a3345375565d594753_31852.png', 'label': np.str_('l£4SuV]YGS'), 'output': 'L£4SuV]YGS', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/462e32553023597dc2a32c_44847.png', 'label': np.str_('F.2U0#Y}£,'), 'output': 'F.2UO#Y}£,', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/466bc3b94529615149546e_68512.png', 'label': np.str_('FkùE)aQITn'), 'output': 'FKùE)aQITn', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/4170573067286e4a6d3b_60892.png', 'label': np.str_('ApW0g(nJm;'), 'output': 'ApWOg(nJm;', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/4b6a5667434a2e736c4b_23053.png', 'label': np.str_('KjVgCJ.slK'), 'output': 'KJVgCJ.sLK', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/5a26717d743b335d2c70_63095.png', 'label': np.str_('Z&q}t;3],p'), 'output': 'z&q}t;3],p', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/53476a5a30477b524cc3b9_80662.png', 'label': np.str_('SGjZ0G{RLù'), 'output': 'SGJZOG{RLù', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/c2a37b58536c2d7872c3b264_69494.png', 'label': np.str_('£{XSl-xròd'), 'output': '£{XSL-Xròd', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/557e2f516b32c3a84d7474_50709.png', 'label': np.str_('U~/Qk2èMtt'), 'output': 'U~,Qk2èMtt', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/23336e6f6f72e282ac682f25_67685.png', 'label': np.str_('#3noor€h/%'), 'output': '#3noor€h,%', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/537263366a2b7b6d3966_10295.png', 'label': np.str_('Src6j+{m9f'), 'output': 'Src6J+{m9f', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/6cc2a36c23594c6f726b4f_67577.png', 'label': np.str_('l£l#YLorkO'), 'output': 'L£L#YLorKO', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/665c304f754a3e672f53_63363.png', 'label': np.str_('f\\0OuJ>g/S'), 'output': 'AOOuJ>g,S', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/PTS55F/623b6d77376b797d2fc3ac_38174.png', 'label': np.str_('b;mw7ky}/ì'), 'output': 'b;mw7Ky}4', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/2b2b352c2845626a2f73_47098.png', 'label': np.str_('++5,(Ebj/s'), 'output': '++5,(Ebj,s', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/546b39796f6c5772367b_25651.png', 'label': np.str_('Tk9yolWr6{'), 'output': 'TK9yoLWr6{', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/55352130495548533158_58481.png', 'label': np.str_('U5!0IUHS1X'), 'output': 'U5!OIUHS1X', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/704a443027293a737624_87205.png', 'label': np.str_("pJD0'):sv$"), 'output': "pJDO'):sv$", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/33794e6ac3b9233a483e59_95449.png', 'label': np.str_('3yNjù#:H>Y'), 'output': '3yNJù#:H>Y', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/c3a9714b5c486945214e6c_66278.png', 'label': np.str_('éqK\\HiE!Nl'), 'output': 'éqK\\HiE!NL', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/6d5975543a3c24305975_38246.png', 'label': np.str_('mYuT:<$0Yu'), 'output': 'mYuT:<$OYu', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/33c3ac46c3b268247d30e282ac64_48060.png', 'label': np.str_('3ìFòh$}0€d'), 'output': '3ìFòh$}O€d', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/456e3a27273e564f2e3f_21537.png', 'label': np.str_("En:''>VO.?"), 'output': 'En:">VO.?', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/6961686b7a38473b5269_25763.png', 'label': np.str_('iahkz8G;Ri'), 'output': 'iahKz8G;Ri', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/507e7d30c3a9555c682b69_99176.png', 'label': np.str_('P~}0éU\\h+i'), 'output': 'P~}oéU\\h+i', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/7e2c6c61c3a8376c5c6627_95980.png', 'label': np.str_("~,laè7l\\f'"), 'output': "~,Laè7L\\f'", 'edit_distance': 2}
# {'path': '../dataset/words_dataset/PTS55F/353ac3ac77453e386a2734_60839.png', 'label': np.str_("5:ìwE>8j'4"), 'output': "5:ìwE>8J'4", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/3ac3ac397042617a512843_91983.png', 'label': np.str_(':ì9pBazQ(C'), 'output': ':ì9pBazQ(c', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/c2b0295850752630725c46_63950.png', 'label': np.str_('°)XPu&0r\\F'), 'output': '°)XPu&or\\F', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/c2a36f6c67722c3c3ac3a832_92975.png', 'label': np.str_('£olgr,<:è2'), 'output': '£oLgr,<:è2', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/426965282f6421334976_94127.png', 'label': np.str_('Bie(/d!3Iv'), 'output': 'Bie(,d!3Iv', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/34412061237854784e48_87979.png', 'label': np.str_('4A a#xTxNH'), 'output': '4Aa#xTxNH', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/203f6e776378745ce282ac40_51486.png', 'label': np.str_(' ?nwcxt\\€@'), 'output': '?nWcXt\\€@', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/PTS55F/56403e3139c3b94e635a39_42797.png', 'label': np.str_('V@>19ùNcZ9'), 'output': 'V@>19ùNcz9', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/4c543659646534353074_51682.png', 'label': np.str_('LT6Yde450t'), 'output': 'LT6Yde45Ot', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/PTS55F/783f2b787848c2a3676d53_97623.png', 'label': np.str_('x?+xxH£gmS'), 'output': 'X?+XXH£gmS', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Courier Prime/2c2dc2a3494f6130322f45_88210.png', 'label': np.str_(',-£IOa02/E'), 'output': ',-£Ioa02,E', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Courier Prime/5d324a4d43334e36627a_46409.png', 'label': np.str_(']2JMC3N6bz'), 'output': ']2OMC3N6bz', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/2f516f50274f533621c2b0_86146.png', 'label': np.str_("/QoP'OS6!°"), 'output': ",Q°P'oS6!°", 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Courier Prime/3f564fc3a8582b5c382c51_80619.png', 'label': np.str_('?VOèX+\\8,Q'), 'output': '?VoèX+\\8,Q', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/3a3f5b532c2fc2b0767d51_92493.png', 'label': np.str_(':?[S,/°v}Q'), 'output': ':?[S,,°v}Q', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/c3a9537e495a7b4b6f6a27_56423.png', 'label': np.str_("éS~IZ{Koj'"), 'output': "éS~IZ{K°j'", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/c2a354505b757e2f7bc3b265_83260.png', 'label': np.str_('£TP[u~/{òe'), 'output': '£TP[u~,{òe', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/292f3142614fc3a9745721_31194.png', 'label': np.str_(')/1BaOétW!'), 'output': '),1BaoétW!', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Courier Prime/2f214d50356d654a5c38_44118.png', 'label': np.str_('/!MP5meJ\\8'), 'output': ',!MP5meO\\8', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Courier Prime/6f724055595063e282ac323a_80005.png', 'label': np.str_('or@UYPc€2:'), 'output': '°r@UYPc€2:', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/3be282ac73c3b93bc2a3516f276d_67849.png', 'label': np.str_(";€sù;£Qo'm"), 'output': ";€sù;£Q°'m", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/662865554c616ac3ac6942_16377.png', 'label': np.str_('f(eULajìiB'), 'output': 'f(eULaJìiB', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/403957645472492f2e74_11049.png', 'label': np.str_('@9WdTrI/.t'), 'output': '@9WdTrI,.t', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/7168742e5442612071c3a9_76904.png', 'label': np.str_('qht.TBa qé'), 'output': 'qht.TBaqé', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/3e6a33c3a8214f2d634579_75089.png', 'label': np.str_('>j3è!O-cEy'), 'output': '>j3è!o-cEy', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/6b4a7d36c3b25156765962_39364.png', 'label': np.str_('kJ}6òQVvYb'), 'output': 'kO}6òQVvYb', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/722c2d544fc3a83e376f5c_94198.png', 'label': np.str_('r,-TOè>7o\\'), 'output': 'r,-TOè>7°\\', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/2f6440c3ac315247517b61_68153.png', 'label': np.str_('/d@ì1RGQ{a'), 'output': ',d@ì1RGQ{a', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/363a67583969573c2026_88572.png', 'label': np.str_('6:gX9iW< &'), 'output': '6:gX9iW<&', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/c2b058c2a36b6e4b4f285b55_42857.png', 'label': np.str_('°X£knKO([U'), 'output': '°X£knKo([U', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/67376a34374745317547_92525.png', 'label': np.str_('g7j47GE1uG'), 'output': 'g7J47GE1uG', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/4f5c7b3b7537332f2859_82725.png', 'label': np.str_('O\\{;u73/(Y'), 'output': 'o\\{;u73,(Y', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Courier Prime/49272d524a514c2c3171_20187.png', 'label': np.str_("I'-RJQL,1q"), 'output': "I'-ROQL,1q", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/3e3e3e30355b387b3778_55976.png', 'label': np.str_('>>>05[8{7x'), 'output': '>>>05[8{7X', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/7824372d48543e57777a_54828.png', 'label': np.str_('x$7-HT>Wwz'), 'output': 'X$7-HT>Wwz', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/563b5ce282ac2b4e7850616a_99784.png', 'label': np.str_('V;\\€+NxPaj'), 'output': 'V;\\€+NXPaj', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/3827506f702f5421305a_20943.png', 'label': np.str_("8'Pop/T!0Z"), 'output': "8'P°p,T!0Z", 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Courier Prime/7268485070746a2d6f41_51379.png', 'label': np.str_('rhHPptj-oA'), 'output': 'rhHPptJ-°A', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Courier Prime/68774cc3ac4871e282ac7ac2a32f_59006.png', 'label': np.str_('hwLìHq€z£/'), 'output': 'hwLìHq€z£,', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/204a545a613e44563646_47418.png', 'label': np.str_(' JTZa>DV6F'), 'output': 'OTZa>DV6F', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Courier Prime/2d4c2f616b504d484177_22436.png', 'label': np.str_('-L/akPMHAw'), 'output': '-L,akPMHAw', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/4a2759715be282ac2f496861_81960.png', 'label': np.str_("J'Yq[€/Iha"), 'output': "O'Yq[€,Iha", 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Courier Prime/632046c2a35746c3acc3b2234d_30474.png', 'label': np.str_('c F£WFìò#M'), 'output': 'cF£WFìò#M', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/7a4133782053c3b9337d23_63303.png', 'label': np.str_('zA3x Sù3}#'), 'output': 'zA3xSù3}#', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/2b7b61e282ac53703549782b_16083.png', 'label': np.str_('+{a€Sp5Ix+'), 'output': '+{a€Sp5IX+', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/697d634b4a4167c3b2c3a937_84196.png', 'label': np.str_('i}cKJAgòé7'), 'output': 'i}ckoAgòé7', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Courier Prime/6348376b4cc3b955c3a8e282ac7d_31106.png', 'label': np.str_('cH7kLùUè€}'), 'output': 'cH7KLùUè€}', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/73554d28632541202133_97441.png', 'label': np.str_('sUM(c%A !3'), 'output': 'sUM(c%A!3', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/64c3b93a4a766137495c7a_35163.png', 'label': np.str_('dù:Jva7I\\z'), 'output': 'dù:Ova7I\\z', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/5b592f28585a41372f63_71081.png', 'label': np.str_('[Y/(XZA7/c'), 'output': '[Y,(XZA7,c', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Courier Prime/c3b26d5a77c3b2386868406f_68497.png', 'label': np.str_('òmZwò8hh@o'), 'output': 'òmZwò8hh@°', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/78726a5146c3b97b317b37_55820.png', 'label': np.str_('xrjQFù{1{7'), 'output': 'xrJQFù{1{7', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/32624a72254a7e5a2e77_26898.png', 'label': np.str_('2bJr%J~Z.w'), 'output': '2bOr%O~Z.w', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Courier Prime/7ac2b031396f6b20676a2c_48744.png', 'label': np.str_('z°19ok gj,'), 'output': 'z°19°kgj,', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Courier Prime/3c207e466a506b365c27_37600.png', 'label': np.str_("< ~FjPk6\\'"), 'output': "<~FjPk6\\'", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/4125c2a32d6224554dc3a820_12817.png', 'label': np.str_('A%£-b$UMè '), 'output': 'A%£-b$UMè', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/30484869624e6f53332d_45188.png', 'label': np.str_('0HHibNoS3-'), 'output': '0HHibN°S3-', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime/6b4f4b392977514b6367_73795.png', 'label': np.str_('kOK9)wQKcg'), 'output': 'KOK9)wQKcg', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/38457346362e31303356_96477.png', 'label': np.str_('8EsF6.103V'), 'output': '8EsF6.1O3V', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/4ac3ac6b732c4c5a2d7956_72168.png', 'label': np.str_('Jìks,LZ-yV'), 'output': 'Jìks,Lz-yV', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/277a7a2c7a5c5a504572_82922.png', 'label': np.str_("'zz,z\\ZPEr"), 'output': "'zz,z\\zPEr", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/6b545d553e7b4677787e_91501.png', 'label': np.str_('kT]U>{Fwx~'), 'output': 'KT]U>{Fwx~', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/33633420635b75796c6a_78110.png', 'label': np.str_('3c4 c[uylj'), 'output': '3c4c[uylJ', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Oswald-Regular/c3b952584e572752c3b2377e_10133.png', 'label': np.str_("ùRXNW'Rò7~"), 'output': "ùRxNW'Rò7~", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/4fc3b2e282ac5d59354f486764_60710.png', 'label': np.str_('Oò€]Y5OHgd'), 'output': 'oò€]Y5oHgd', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Oswald-Regular/6e3a20236a4329e282ac2667_13879.png', 'label': np.str_('n: #jC)€&g'), 'output': 'n:#JC)€&g', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Oswald-Regular/56323228c3ac6158557368_30132.png', 'label': np.str_('V22(ìaXUsh'), 'output': 'V22naXUsh', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Oswald-Regular/4d7756c3b93b676f6b5c29_31433.png', 'label': np.str_('MwVù;gok\\)'), 'output': 'MwVù;goK\\)', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/666b6179c2a32c686ec2a372_35195.png', 'label': np.str_('fkay£,hn£r'), 'output': 'fKay£,hn£r', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/6277255b5b2b385c7361_51430.png', 'label': np.str_('bw%[[+8\\sa'), 'output': 'bwO%o[[+8\\sa', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Oswald-Regular/615c4130244e2f41c2b03a_46044.png', 'label': np.str_('a\\A0$N/A°:'), 'output': 'a\\AO$N7A°:', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Oswald-Regular/2f686f3349625d715263_65758.png', 'label': np.str_('/ho3Ib]qRc'), 'output': '7ho3lb]qRc', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Oswald-Regular/44675266422525e282ac3f61_57695.png', 'label': np.str_('DgRfB%%€?a'), 'output': 'DgRfBO%oO%o€?a', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Oswald-Regular/636a79276ec3a85a757470_19049.png', 'label': np.str_("cjy'nèZutp"), 'output': "cJy'nèZutp", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/7b2b7d7a4755584d79c3b2_69135.png', 'label': np.str_('{+}zGUXMyò'), 'output': '{+}zGUxMyò', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/4b5c34764d6b4736c3a84f_53494.png', 'label': np.str_('K\\4vMkG6èO'), 'output': 'K\\4vMkG6èo', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/7745c2b055352b5a616a31_40730.png', 'label': np.str_('wE°U5+Zaj1'), 'output': 'wE°U5+ZaJ1', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/5744472f4e4ec2a34b3343_49406.png', 'label': np.str_('WDG/NN£K3C'), 'output': 'WDG7NN£K3C', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/c3a9617e693a61266b4a6d_72007.png', 'label': np.str_('éa~i:a&kJm'), 'output': 'éa~i:a&dm', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Oswald-Regular/4d5438257642c2a3c3ac3940_82503.png', 'label': np.str_('MT8%vB£ì9@'), 'output': 'MT8 O%ovB£ì9@', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Oswald-Regular/2332c3ac444f31273f472d_95488.png', 'label': np.str_("#2ìDO1'?G-"), 'output': "#2ìDo1'?G-", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/73286d422440592c493f_37427.png', 'label': np.str_('s(mB$@Y,I?'), 'output': 's(mB$@Y,l?', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/24494bc2a3357d41336d5b_57631.png', 'label': np.str_('$IK£5}A3m['), 'output': '$lu5}A3m[', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Oswald-Regular/726d6756304d5a4c5736_10999.png', 'label': np.str_('rmgV0MZLW6'), 'output': 'rmgVOMZLW6', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/254a6c6b527a763a2628_49551.png', 'label': np.str_('%JlkRzv:&('), 'output': 'o%oJ lkRzv:&(', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Oswald-Regular/506a2d253870382b3b58_60434.png', 'label': np.str_('Pj-%8p8+;X'), 'output': 'Pj-o%o8p8+;x', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Oswald-Regular/6b36356e5c62333e336b_58461.png', 'label': np.str_('k65n\\b3>3k'), 'output': 'K65n\\b3>3K', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Oswald-Regular/3923512c7a364b384971_18139.png', 'label': np.str_('9#Q,z6K8Iq'), 'output': '9#Q,z6K8lq', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/39733e3e245464406a41_44111.png', 'label': np.str_('9s>>$Td@jA'), 'output': '9s>>$Td@JA', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/31c2b0416375734c294967_84346.png', 'label': np.str_('1°AcusL)Ig'), 'output': '1°AcusL)lg', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/32583949432f28545624_96833.png', 'label': np.str_('2X9IC/(TV$'), 'output': '2X9lC7(TV$', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Oswald-Regular/c3b25c4f253f546e442e79_57773.png', 'label': np.str_('ò\\O%?TnD.y'), 'output': 'ò\\oo%o?Tn D.y', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Oswald-Regular/6d7d697377305678c2a368_51864.png', 'label': np.str_('m}isw0Vx£h'), 'output': 'm}iswOVx£h', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/65416d68667a673f7e49_43868.png', 'label': np.str_('eAmhfzg?~I'), 'output': 'eAmhfzg?~l', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/4e207537436f5276c3a865_14390.png', 'label': np.str_('N u7CoRvèe'), 'output': 'Nu7CoRvèe', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/2b575d79e282ac56587b394b_83829.png', 'label': np.str_('+W]y€VX{9K'), 'output': '+W]WVx{9K', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Oswald-Regular/7364562f2e5c57e282ac2758_36137.png', 'label': np.str_("sdV/.\\W€'X"), 'output': "sdV7.\\W€'X", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/c3a825386a5c71632f507a_84767.png', 'label': np.str_('è%8j\\qc/Pz'), 'output': 'èo%o8j\\qc7Pz', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Oswald-Regular/49517937444f323c3920_11860.png', 'label': np.str_('IQy7DO2<9 '), 'output': 'lQy7DO2<9', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Oswald-Regular/5c5034266a67664e7d5d_59821.png', 'label': np.str_('\\P4&jgfN}]'), 'output': '\\P4&jdN}]', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Oswald-Regular/7e7a30246739e282ac3a3c4b_24560.png', 'label': np.str_('~z0$g9€:<K'), 'output': '~zo$g9€:<K', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/62c3b279796a41612e5121_23252.png', 'label': np.str_('bòyyjAa.Q!'), 'output': 'bòyyJAa.Q!', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/c3b22f5a7b443b31615079_54654.png', 'label': np.str_('ò/Z{D;1aPy'), 'output': 'ò7z{D;1aPy', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Oswald-Regular/63576579c3a8616a3c2b20_97817.png', 'label': np.str_('cWeyèaj<+ '), 'output': 'cWeyèaJ<+', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Oswald-Regular/275cc3a8683e25312e266f_95074.png', 'label': np.str_("'\\èh>%1.&o"), 'output': "' \\èh>o%o1.&o", 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Oswald-Regular/53265c2c5c2e5c6658e282ac_64439.png', 'label': np.str_('S&\\,\\.\\fX€'), 'output': 'S&\\,\\.\\fx€', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/44456be282ac687244562423_70438.png', 'label': np.str_('DEk€hrDV$#'), 'output': 'DEK€hrDV$#', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/30244469547850c3b94659_48417.png', 'label': np.str_('0$DiTxPùFY'), 'output': 'o$DiTxPùFY', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/3c61682374686b4f3973_80844.png', 'label': np.str_('<ah#thkO9s'), 'output': '<ah#thko9s', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/5927596133673b6bc3b23f_59242.png', 'label': np.str_("Y'Ya3g;kò?"), 'output': "Y'Ya3g;Kò?", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/45443a6f4652257b204f_48378.png', 'label': np.str_('ED:oFR%{ O'), 'output': 'ED:oFRO%o{O', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Oswald-Regular/733c4f62c2b0244061464d_36456.png', 'label': np.str_('s<Ob°$@aFM'), 'output': 's<ob°$@aFM', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/3258253435653e48405a_70268.png', 'label': np.str_('2X%45e>H@Z'), 'output': '2XO%o45e>H@Z', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Oswald-Regular/6c2d3b2f5328c2b0347d5a_54786.png', 'label': np.str_('l-;/S(°4}Z'), 'output': 'l-;7S(°4}Z', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Oswald-Regular/57252d70c3a820427a6ac3ac_85928.png', 'label': np.str_('W%-pè Bzjì'), 'output': 'Wo%o-pèBzjì', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Oswald-Regular/38534a4941386b66c2a364_48446.png', 'label': np.str_('8SJIA8kf£d'), 'output': '8SJlA8Kf£d', 'edit_distance': 2}
# ...
# {'path': '../dataset/words_dataset/Courier Prime Bold/6e4665653e6730e282ac21c3ac_76347.png', 'label': np.str_('nFee>g0€!ì'), 'output': 'nFee>g0C!ì', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime Bold/2f573a594955686cc3a94c_97259.png', 'label': np.str_('/W:YIUhléL'), 'output': ',W:YIUhléL', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime Bold/502c56646f773928c3a875_85561.png', 'label': np.str_('P,Vdow9(èu'), 'output': 'p,Vd°W9(èu', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Courier Prime Bold/6f4b713f472c537a254b_54625.png', 'label': np.str_('oKq?G,Sz%K'), 'output': '°Kq?G,Sz%K', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime Bold/2375443c64694b2d24e282ac_95108.png', 'label': np.str_('#uD<diK-$€'), 'output': '#uD<diK-$c', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime Bold/723b3561696c6868736b_57476.png', 'label': np.str_('r;5ailhhsk'), 'output': 'r;5ailhhaK', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Courier Prime Bold/69504876544675342d45_83678.png', 'label': np.str_('iPHvTFu4-E'), 'output': 'ipHvTFu4-E', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime Bold/e282ac6537584368502453e282ac_52517.png', 'label': np.str_('€e7XChP$S€'), 'output': 'Ce7XChP$SC', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Courier Prime Bold/3f4d68632f2571794d3c_80569.png', 'label': np.str_('?Mhc/%qyM<'), 'output': '?Mhc,%qyM<', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime Bold/5a6221626b21786d6568_91245.png', 'label': np.str_('Zb!bk!xmeh'), 'output': 'zb!bK!xmeh', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Courier Prime Bold/246d656f617a4d644e47_75222.png', 'label': np.str_('$meoazMdNG'), 'output': '$me°azMdNG', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime Bold/40597477c3a9542557444f_57079.png', 'label': np.str_('@YtwéT%WDO'), 'output': '@YtWéT%WD°', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Courier Prime Bold/7b4e2457c3b96c39c3ace282ac66_23438.png', 'label': np.str_('{N$Wùl9ì€f'), 'output': '{N$Wùl9ìcf', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime Bold/5ae282ac5b63356252c2a33e3f_80585.png', 'label': np.str_('Z€[c5bR£>?'), 'output': 'Zc[c5bR£>?', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime Bold/6a264f517bc3b220c3ac2063_12839.png', 'label': np.str_('j&OQ{ò ì c'), 'output': 'j&°Q{òìc', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Courier Prime Bold/3b755b433e713734c3a827_82849.png', 'label': np.str_(";u[C>q74è'"), 'output': ";u[c>q74è'", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime Bold/7e2973765d2fc2a338354e_19597.png', 'label': np.str_('~)sv]/£85N'), 'output': '~)av],£85N', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Courier Prime Bold/5021c3a9597a27c2a3482c57_86957.png', 'label': np.str_("P!éYz'£H,W"), 'output': "p!éYz'£H,W", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Courier Prime Bold/6b5d284a322d35e282ac6237_68568.png', 'label': np.str_('k](J2-5€b7'), 'output': 'k](J2-5cb7', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/656a2434732dc3b9484a38_65169.png', 'label': np.str_('ej$4s-ùHJ8'), 'output': 'eJ$As-ùHJ8', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/546a7e5a52c3b979c3b94a32_31522.png', 'label': np.str_('Tj~ZRùyùJ2'), 'output': 'TJ~ZRùyùJ2', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/353b59236d207b592466_87798.png', 'label': np.str_('5;Y#m {Y$f'), 'output': '5;Y#m{Y$r', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/43702961472f2d425653_60458.png', 'label': np.str_('Cp)aG/-BVS'), 'output': 'cp)aG,-Bvs', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/5562553c4a203f3a3724_11321.png', 'label': np.str_('UbU<J ?:7$'), 'output': 'UbU<J?:7$', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/643c4c6bc3b233727ec3a8c3ac_22764.png', 'label': np.str_('d<Lkò3r~èì'), 'output': 'd<Lbò3r~èì', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/c3b251733b6a6d787a40c2b0_91336.png', 'label': np.str_('òQs;jmxz@°'), 'output': 'òQs;jmxz4°', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/5c4e7b7053c3a827e282acc2b050_55999.png', 'label': np.str_("\\N{pSè'€°P"), 'output': "\\N{psè'e°P", 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/2dc3b24f46415826246736_52499.png', 'label': np.str_('-òOFAX&$g6'), 'output': '-òoFAxb$g6', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/573f4d4e365778c3b96631_83175.png', 'label': np.str_('W?MN6Wxùf1'), 'output': 'w?MN6wxùr1', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/7234c3ac432d31436d7423_32382.png', 'label': np.str_('r4ìC-1Cmt#'), 'output': 'rAìC-1Cmt#', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/2b582b3163c3a9246230c2a3_65964.png', 'label': np.str_('+X+1cé$b0£'), 'output': '+x+1cé$bo£', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/3e686d2320627b4c2979_67111.png', 'label': np.str_('>hm# b{L)y'), 'output': '>hm#b{L)y', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/7e4c574c4a25414d2823_17552.png', 'label': np.str_('~LWLJ%AM(#'), 'output': '~LwLJ%AM(#', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/33582c69665cc3a969705a_82120.png', 'label': np.str_('3X,if\\éipZ'), 'output': '3X,ihéipZ', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/3976446f314b3c502154_69189.png', 'label': np.str_('9vDo1K<P!T'), 'output': '9vDo1l<<P!T', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/e282ac264361643a59676f3e_13716.png', 'label': np.str_('€&Cad:Ygo>'), 'output': 'ebcad:YgO>', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/267e27584e26e282ac6f48c3ac_73539.png', 'label': np.str_("&~'XN&€oHì"), 'output': "b~'XNbeoHì", 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/4b6c7e68c3a9c2b0445b547d_85837.png', 'label': np.str_('Kl~hé°D[T}'), 'output': 'l<l~hé°D[T}', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/3b5d7d4b24c3a85a307223_30582.png', 'label': np.str_(';]}K$èZ0r#'), 'output': ';]}l<$èzor#', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/405c24613559275be282ac69_21260.png', 'label': np.str_("@\\$a5Y'[€i"), 'output': "4\\$a5Y'[ei", 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/394c6d6369284c73736b_49429.png', 'label': np.str_('9Lmci(Lssk'), 'output': '9Lmci(Lssb', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/6c5d777065c3ac553a2627_32840.png', 'label': np.str_("l]wpeìU:&'"), 'output': "l]wpeìU:b'", 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/c3a94d6c30c2a379784c6765_44711.png', 'label': np.str_('éMl0£yxLge'), 'output': 'éMlo£pLge', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/71477b23632727765a5d_68506.png', 'label': np.str_("qG{#c''vZ]"), 'output': 'qG{#c"vZ]', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/357b72776c55564e5230_29843.png', 'label': np.str_('5{rwlUVNR0'), 'output': '5{rwlUVNRO', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/77544b44763e3a3129c3a8_27492.png', 'label': np.str_('wTKDv>:1)è'), 'output': 'wTl<Dv>:1)è', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/203474332b262b3c616a_23625.png', 'label': np.str_(' 4t3+&+<aj'), 'output': 'At3+b+<aJ', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/7863486f61615bc2b0646a_82286.png', 'label': np.str_('xcHoaa[°dj'), 'output': 'xcHoaa[°dJ', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/2d40685442313e29c3acc3a8_28821.png', 'label': np.str_('-@hTB1>)ìè'), 'output': '-4hTB1>)ìè', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/73636c683061c2b0732c43_24768.png', 'label': np.str_('sclh0a°s,C'), 'output': 'sclhOa°s,C', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/3bc2b0355b7a695a2c4b4c_58933.png', 'label': np.str_(';°5[ziZ,KL'), 'output': ';°5[ziz,l<L', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/c3ac3c6b5754586fc2b05361_17079.png', 'label': np.str_('ì<kWTXo°Sa'), 'output': 'ì<bwTxo°sa', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/2c6a4d463451694e5563_67754.png', 'label': np.str_(',jMF4QiNUc'), 'output': ',jMFAQiNUc', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/2e326b58617d52704332_24709.png', 'label': np.str_('.2kXa}RpC2'), 'output': '.2bxa}Rpc2', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/6ce282ac2578c3a94223545647_29062.png', 'label': np.str_('l€%xéB#TVG'), 'output': 'le%xéB#WG', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/652f312e305541406129_14903.png', 'label': np.str_('e/1.0UA@a)'), 'output': 'e,1.OUA4a)', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/744dc2a375e282ac6531482d2c_76387.png', 'label': np.str_('tM£u€e1H-,'), 'output': 'tM£Uee1H-,', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/50797161c3a82928595320_34067.png', 'label': np.str_('Pyqaè)(YS '), 'output': 'Wqaè)(YS', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/c3b26841443c5c4be282ac3e3b_26707.png', 'label': np.str_('òhAD<\\K€>;'), 'output': 'òhAD<\\l<e>;', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/667e3be282ac2f3435e282ac7954_36172.png', 'label': np.str_('f~;€/45€yT'), 'output': 'r~;e,A5eyT', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Sansation-Bold/41545b7a3330482c397b_30653.png', 'label': np.str_('AT[z30H,9{'), 'output': 'AT[z3OH,9{', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/2f41463c213c24686e7b_22035.png', 'label': np.str_('/AF<!<$hn{'), 'output': ',AF<!<$hn{', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/77455dc3b93f55422b5730_43931.png', 'label': np.str_('wE]ù?UB+W0'), 'output': 'wE]ù?UB+WO', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/23555b325a5849535c50_12541.png', 'label': np.str_('#U[2ZXIS\\P'), 'output': '#U[2zxls\\P', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/62664dc2a33e29503f512e_20408.png', 'label': np.str_('bfM£>)P?Q.'), 'output': 'brM£>)P?Q.', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/70786c4479c3b971402846_64580.png', 'label': np.str_('pxlDyùq@(F'), 'output': 'pxlDyùq4(F', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/3079364c626535584dc3a9_70629.png', 'label': np.str_('0y6Lbe5XMé'), 'output': 'Oy6Lbe5XMé', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/777e7d3b35304a77c3ac35_20270.png', 'label': np.str_('w~};50Jwì5'), 'output': 'W~};5oJWì5', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/394e292643213e322464_41151.png', 'label': np.str_('9N)&C!>2$d'), 'output': '9N)bC!>2$d', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/6a703275532bc2b07b4778_33239.png', 'label': np.str_('jp2uS+°{Gx'), 'output': 'Jp2uS+°{Gx', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/5072267dc3b26f7451257b_87880.png', 'label': np.str_('Pr&}òotQ%{'), 'output': 'Prb}òotQ%{', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/3f3444402e413e556258_69005.png', 'label': np.str_('?4D@.A>UbX'), 'output': '?AD4.A>Ubx', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/36c2a355447878364d7b5c_13599.png', 'label': np.str_('6£UDxx6M{\\'), 'output': '6£UD@6M{\\', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/63343b6552506f7657c2b0_83541.png', 'label': np.str_('c4;eRPovW°'), 'output': 'cA;eRPovW°', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/7a7a573a687064504d7e_52510.png', 'label': np.str_('zzW:hpdPM~'), 'output': 'zzw:hpdPM~', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/c3b2357775774e4232797b_84011.png', 'label': np.str_('ò5wuwNB2y{'), 'output': 'ò5WuWNB2y{', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/6d7e4b404a41527e2951_47189.png', 'label': np.str_('m~K@JAR~)Q'), 'output': 'm~l<4JAR~)Q', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/5c20c3ac54615a7427c2b074_77969.png', 'label': np.str_("\\ ìTaZt'°t"), 'output': "\\ìTazt'°t", 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/4fc3b9c3a8684b2f2625364c_60353.png', 'label': np.str_('OùèhK/&%6L'), 'output': 'oùèhl<,b%6L', 'edit_distance': 5}
# {'path': '../dataset/words_dataset/Sansation-Bold/27494026496d2c6d3641_64672.png', 'label': np.str_("'I@&Im,m6A"), 'output': "'l4blm,m6A", 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/c3ac494c407b2453724e72_99004.png', 'label': np.str_('ìIL@{$SrNr'), 'output': 'ìlL4{$srNr', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/7d424a3a4e6249483829_54886.png', 'label': np.str_('}BJ:NbIH8)'), 'output': '}BJ:NblH8)', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/3171314d734b6b20c3a947_98459.png', 'label': np.str_('1q1MsKk éG'), 'output': '1q1Msl<béG', 'edit_distance': 3}
# {'path': '../dataset/words_dataset/Sansation-Bold/3a407a21645821536632_51210.png', 'label': np.str_(':@z!dX!Sf2'), 'output': ':4z!dx!sr2', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/5b3174702b73204c37c3a9_57921.png', 'label': np.str_('[1tp+s L7é'), 'output': '[1tp+sL7é', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/36496852524e6f446b42_54911.png', 'label': np.str_('6IhRRNoDkB'), 'output': '6lhRRNoDbB', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/2526494553c3ac5b2bc3b240_57155.png', 'label': np.str_('%&IESì[+ò@'), 'output': '%blEsì[+ò4', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/75454b6b4363242c3052_70722.png', 'label': np.str_('uEKkCc$,0R'), 'output': 'uEl<bCc$,OR', 'edit_distance': 4}
# {'path': '../dataset/words_dataset/Sansation-Bold/3f4053c3ac764821553942_11569.png', 'label': np.str_('?@SìvH!U9B'), 'output': '?4sìvH!U9B', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/425c596a676745257d52_46101.png', 'label': np.str_('B\\YjggE%}R'), 'output': 'B\\YJggE%}R', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/5456517a523855505224_34135.png', 'label': np.str_('TVQzR8UPR$'), 'output': 'WQzR8UPR$', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/576a3848595b7a57683b_84473.png', 'label': np.str_('Wj8HY[zWh;'), 'output': 'WJ8HY[zWh;', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/694146c3b253307b334965_79232.png', 'label': np.str_('iAFòS0{3Ie'), 'output': 'iAFòSO{3le', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/4d466f746a4156534749_17422.png', 'label': np.str_('MFotjAVSGI'), 'output': 'MFotJAVSGl', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/403e46486e556f6661c3ac_12338.png', 'label': np.str_('@>FHnUofaì'), 'output': '4>FHnUoraì', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/372662736351444dc3a842_73018.png', 'label': np.str_('7&bscQDMèB'), 'output': '7bbscQDMèB', 'edit_distance': 1}
# {'path': '../dataset/words_dataset/Sansation-Bold/4971496758643942c2a37e_46212.png', 'label': np.str_('IqIgXd9B£~'), 'output': 'lqlgXd9B£~', 'edit_distance': 2}
# {'path': '../dataset/words_dataset/Sansation-Bold/62653a5c3e7e542720c3a9_45434.png', 'label': np.str_("be:\\>~T' é"), 'output': "be:\\>~T'é", 'edit_distance': 1}
